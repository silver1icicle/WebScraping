# %% [markdown]
# # Python's requests library - Basic Usage and Examples

# %% [markdown]
# ## Reference URL:
# ### URL:
# #### https://blog.hartleybrody.com/web-scraping-cheat-sheet/#making-simple-requests
# #### https://brennan.io/2016/03/02/logging-in-with-requests/
# #### https://realpython.com/python-requests/
#
# ## Theory:
# ### requests API ensures that all forms of HTTP request are obvious.
# ### Possible HTTP requests: GET/POST/PUSH/DELETE/HEAD/OPTIONS.
#
# ## HTTP request protocols:
#   ### >>> r = requests.get('https://api.github.com/events')
#   ### >>> r = requests.put('https://httpbin.org/put', data = {'key':'value'})
#   ### >>> r = requests.delete('https://httpbin.org/delete')
#   ### >>> r = requests.head('https://httpbin.org/get')
#   ### >>> r = requests.options('https://httpbin.org/get')
#
# ## Status Coces:
#     200/202 - Successful operation
#     204     - No Content to show
#     400     - Not Found/Bad request/ Request body incorrect
#     401     - Unauthorized access/ Token invlaid or expired
#     403     - Forbidden
#     404     - URL incorrect/ Page not found
#     429     - Too many requests
#     500     - Internal server error
#
#  ### Lis of Github ReST API's:
#  #### https://api.github.com/
#  #### https://apidocs.symantec.com/

# %% [markdown]
# ## Import required module

# %%
import requests

# %% [markdown]
# ## Submit a GET request & print the response

# %%
r = requests.get("https://api.github.com/events")    # Response Object
print(r.text)
# Out:
# [{"id":"9229321868","type":"PushEvent","actor":{"id":17232997,"login":"akmaz","display_login":"akmaz","gravatar_id":"","url":"https://api.github.com/users/akmaz","avatar_url":"https://avatars.githubusercontent.com/u/17232997?"},"repo":{"id":175255662,"name":"akmaz/example_algorithms","url":"https://api.github.com/repos/akmaz/example_algorithms"},"payload":{"push_id":3393077361,"size":1,"distinct_size":1,"ref":"refs/heads/master","head":"82b0f43cb86394642d85850ba4868978ba55d72e","before":"09b579ff143b21ef574072746bce90953054ac52","commits":[{"sha":"82b0f43cb86394642d85850ba4868978ba55d72e","author":{"email":"aleksandra8mazur@gmail.com","name":"Aleksandra"},"message":"Added bubblesort algorithm.","distinct":true,"url":"https://api.github.com/repos/akmaz/example_algorithms/commits/82b0f43cb86394642d85850ba4868978ba55d72e"}]},"public":true,"created_at":"2019-03-12T19:04:24Z"},{"id":"9229321863","type":"PullRequestEvent","actor":{"id":31713290,"login":"Katzesama","display_login":"Katzesama","gravatar_id":"","url":"https://api.github.com/users/Katzesama","avatar_url":"https://avatars.githubusercontent.com/u/31713290?"},"repo":{"id":171518055,"name":"Katzesama/CMPUT404-project-socialdistribution","url":"https://api.github.com/repos/Katzesama/CMPUT404-project-socialdistribution"},"payload":{"action":"opened","number":10,"pull_request":{"url":"https://api.github.com/repos/Katzesama/CMPUT404-project-socialdistribution/pulls/10","id":260498054,"node_id":"MDExOlB1bGxSZXF1ZXN0MjYwNDk4MDU0","html_url":"https://github.com/Katzesama/CMPUT404-project-socialdistribution/pull/10","diff_url":"https://github.com/Katzesama/CMPUT404-project-socialdistribution/pull/10.diff","patch_url":"https://github.com/Katzesama/CMPUT404-project-socialdistribution/pull/10.patch","issue_url":"https://api.github.com/repos/Katzesama/CMPUT404-project-socialdistribution/issues/10","number":10,"state":"open","locked":false,"title":"Wyang2","user":{"login":"Katzesama","id":31713290,"node_id":"MDQ6VXNlcjMxNzEzMjkw","avatar_url":"https://avatars0.githubusercontent.com/u/31713290?v=4","gravatar_id":"","url":"https://api.github.com/users/Katzesama","html_url":"https://github.com/Katzesama","followers_url":"https://api.github.com/users/Katzesama/followers","following_url":"https://api.github.com/users/Katzesama/following{/other_user}","gists_url":"https://api.github.com/users/Katzesama/gists{/gist_id}","starred_url":"https://api.github.com/users/Katzesama/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/Katzesama/subscriptions","organizations_url":"https://api.github.com/users/Katzesama/orgs","repos_url":"https://api.github.com/users/Katzesama/repos","events_url":"https://api.github.com/users/Katzesama/events{/privacy}","received_events_url":"https://api.github.com/users/Katzesama/received_events","type":"User","site_admin":false},"body":"","created_at":"2019-03-12T19:04:23Z","updated_at":"2019-03-12T19:04:23Z","closed_at":null,"merged_at":null,"merge_commit_sha":null,"assignee":null,"assignees":[],"requested_reviewers":[],"requested_teams":[],"labels":[],"milestone":null,"commits_url":"https://api.github.com/repos/Katzesama/CMPUT404-project-socialdistribution/pulls/10/commits","review_comments_url":"https://api.github.com/repos/Katzesama/CMPUT404-project-socialdistribution/pulls/10/comments","review_comment_url":"https://api.github.com/repos/Katzesama/CMPUT404-project-socialdistribution/pulls/comments{/number}","comments_url":"https://api.github.com/repos/Katzesama/CMPUT404-project-socialdistribution/issues/10/comments","statuses_url":"https://api.github.com/repos/Katzesama/CMPUT404-project-socialdistribution/statuses/f927d315ada61cd182e1eee773b048517d43889a","head":{"label":"Katzesama:wyang2","ref":"wyang2","sha":"f927d315ada61cd182e1eee773b048517d43889a","user":{"login":"Katzesama","id":31713290,"node_id":"MDQ6VXNlcjMxNzEzMjkw","avatar_url":"https://avatars0.githubusercontent.com/u/31713290?v=4","gravatar_id":"","url":"https://api.github.com/users/ ...

# %% [markdown]
# ## Print the default encoding

# %%
print(r.encoding)
# Out:
# utf-8

# %% [markdown]
# ## Print and check the response status code

# %%
print(r.status_code)
print(r.raise_for_status())

if r.status_code == 200:
    print("Success")
else:
    print("Failure")

    
# NOTE: This code will return 'Success' even if we get a 4xx response.
# Out:
# 200
# None
# Success

# %% [markdown]
# ## Complete Code - Use the same skeleton always

# %%
# Complete Code:-----> Follow this skeleton everywhere

import requests
from requests.exceptions import HTTPError
for url in ['https://api.github.com','https://api.github.com/junkURL']:
    try:
        resp = requests.get(url)
        resp.raise_for_status()
    except HTTPError as err:
        print("HTTP Error occurred:", err) 
    except Exception as err:
        print("Some other error occurred:", err)
    else:
        print("Success")
# Out:
# Success
# HTTP Error occurred: 404 Client Error: Not Found for url: https://api.github.com/junkURL

# %% [markdown]
# ## Ways to print the responses

# %%
resp=requests.get("https://api.github.com")

# METHOD-1
resp.content                                      # Prints the payload - In bytes 
print("+_+_+_+_+_+_+_+_+_+_+_+_+_+_+_+_+_+_+_+_+_+_+_+_+_+_+_+_+_+_+_+_+_+_+_+_+_+_+_+_")

# METHOD-2
resp.text                                         # Prints the payload - In text/ string
'''
NOTE: Decoding bytes to string will require an encoding scheme. requests will try to guess the encoding based on the 
      responses header. In case you arent ok with the guess encoding, you can explicitly provide your encoding using the 
      response.encoding = "xxxxxxxxxx"
'''

# METHOD-3
resp.json()                                      # Prints the payload - In json format
# Out:
# +_+_+_+_+_+_+_+_+_+_+_+_+_+_+_+_+_+_+_+_+_+_+_+_+_+_+_+_+_+_+_+_+_+_+_+_+_+_+_+_
# {'authorizations_url': 'https://api.github.com/authorizations',
#  'code_search_url': 'https://api.github.com/search/code?q={query}{&page,per_page,sort,order}',
#  'commit_search_url': 'https://api.github.com/search/commits?q={query}{&page,per_page,sort,order}',
#  'current_user_authorizations_html_url': 'https://github.com/settings/connections/applications{/client_id}',
#  'current_user_repositories_url': 'https://api.github.com/user/repos{?type,page,per_page,sort}',
#  'current_user_url': 'https://api.github.com/user',
#  'emails_url': 'https://api.github.com/user/emails',
#  'emojis_url': 'https://api.github.com/emojis',
#  'events_url': 'https://api.github.com/events',
#  'feeds_url': 'https://api.github.com/feeds',
#  'followers_url': 'https://api.github.com/user/followers',
#  'following_url': 'https://api.github.com/user/following{/target}',
#  'gists_url': 'https://api.github.com/gists{/gist_id}',
#  'hub_url': 'https://api.github.com/hub',
#  'issue_search_url': 'https://api.github.com/search/issues?q={query}{&page,per_page,sort,order}',
#  'issues_url': 'https://api.github.com/issues',
#  'keys_url': 'https://api.github.com/user/keys',
#  'notifications_url': 'https://api.github.com/notifications',
#  'organization_repositories_url': 'https://api.github.com/orgs/{org}/repos{?type,page,per_page,sort}',
#  'organization_url': 'https://api.github.com/orgs/{org}',
#  'public_gists_url': 'https://api.github.com/gists/public',
#  'rate_limit_url': 'https://api.github.com/rate_limit',
#  'repository_search_url': 'https://api.github.com/search/repositories?q={query}{&page,per_page,sort,order}',
#  'repository_url': 'https://api.github.com/repos/{owner}/{repo}',
#  'starred_gists_url': 'https://api.github.com/gists/starred',
#  'starred_url': 'https://api.github.com/user/starred{/owner}{/repo}',
#  'team_url': 'https://api.github.com/teams',
#  'user_organizations_url': 'https://api.github.com/user/orgs',
#  'user_repositories_url': 'https://api.github.com/users/{user}/repos{?type,page,per_page,sort}',
#  'user_search_url': 'https://api.github.com/search/users?q={query}{&page,per_page,sort,order}',
#  'user_url': 'https://api.github.com/users/{user}'}

# %% [markdown]
# ## Print Headers

# %%
resp.headers
# Out:
# {'Server': 'GitHub.com', 'Date': 'Tue, 12 Mar 2019 19:09:25 GMT', 'Content-Type': 'application/json; charset=utf-8', 'Transfer-Encoding': 'chunked', 'Status': '200 OK', 'X-RateLimit-Limit': '60', 'X-RateLimit-Remaining': '56', 'X-RateLimit-Reset': '1552421364', 'Cache-Control': 'public, max-age=60, s-maxage=60', 'Vary': 'Accept', 'ETag': 'W/"7dc470913f1fe9bb6c7355b50a0737bc"', 'X-GitHub-Media-Type': 'github.v3; format=json', 'Access-Control-Expose-Headers': 'ETag, Link, Location, Retry-After, X-GitHub-OTP, X-RateLimit-Limit, X-RateLimit-Remaining, X-RateLimit-Reset, X-OAuth-Scopes, X-Accepted-OAuth-Scopes, X-Poll-Interval, X-GitHub-Media-Type', 'Access-Control-Allow-Origin': '*', 'Strict-Transport-Security': 'max-age=31536000; includeSubdomains; preload', 'X-Frame-Options': 'deny', 'X-Content-Type-Options': 'nosniff', 'X-XSS-Protection': '1; mode=block', 'Referrer-Policy': 'origin-when-cross-origin, strict-origin-when-cross-origin', 'Content-Security-Policy': "default-src 'none'", 'Content-Encoding': 'gzip', 'X-GitHub-Request-Id': 'C6EF:6B57:9C0DF:167B27:5C8803E5'}

# %% [markdown]
# ## Using the response.headers to get required information

# %%
print(resp.headers['Server'])
print(resp.headers['Content-Type'])    

## Plus point: the headers arent case sensitive
print(resp.headers['server'])
print(resp.headers['conTENT-TYpe'])
# Out:
# GitHub.com
# application/json; charset=utf-8
# GitHub.com
# application/json; charset=utf-8

# %% [markdown]
# # Parameterizing GET requests

# %% [markdown]
# ## Concept of query strings - [I] Passing params in the form of a dictionary

# %%
import requests
res = requests.get('https://api.github.com/search/repositories', 
                   params={'q' : 'requests+language:python'})        # passed params to get() in the form of a dictionary

json_resp = res.json()
print(json_resp)
# Out:
# {'total_count': 7106, 'incomplete_results': False, 'items': [{'id': 1362490, 'node_id': 'MDEwOlJlcG9zaXRvcnkxMzYyNDkw', 'name': 'requests', 'full_name': 'kennethreitz/requests', 'private': False, 'owner': {'login': 'kennethreitz', 'id': 47496974, 'node_id': 'MDEyOk9yZ2FuaXphdGlvbjQ3NDk2OTc0', 'avatar_url': 'https://avatars1.githubusercontent.com/u/47496974?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/kennethreitz', 'html_url': 'https://github.com/kennethreitz', 'followers_url': 'https://api.github.com/users/kennethreitz/followers', 'following_url': 'https://api.github.com/users/kennethreitz/following{/other_user}', 'gists_url': 'https://api.github.com/users/kennethreitz/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/kennethreitz/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/kennethreitz/subscriptions', 'organizations_url': 'https://api.github.com/users/kennethreitz/orgs', 'repos_url': 'https://api.github.com/users/kennethreitz/repos', 'events_url': 'https://api.github.com/users/kennethreitz/events{/privacy}', 'received_events_url': 'https://api.github.com/users/kennethreitz/received_events', 'type': 'Organization', 'site_admin': False}, 'html_url': 'https://github.com/kennethreitz/requests', 'description': 'Python HTTP Requests for Humans™ ✨🍰✨', 'fork': False, 'url': 'https://api.github.com/repos/kennethreitz/requests', 'forks_url': 'https://api.github.com/repos/kennethreitz/requests/forks', 'keys_url': 'https://api.github.com/repos/kennethreitz/requests/keys{/key_id}', 'collaborators_url': 'https://api.github.com/repos/kennethreitz/requests/collaborators{/collaborator}', 'teams_url': 'https://api.github.com/repos/kennethreitz/requests/teams', 'hooks_url': 'https://api.github.com/repos/kennethreitz/requests/hooks', 'issue_events_url': 'https://api.github.com/repos/kennethreitz/requests/issues/events{/number}', 'events_url': 'https://api.github.com/repos/kennethreitz/requests/events', 'assignees_url': 'https://api.github.com/repos/kennethreitz/requests/assignees{/user}', 'branches_url': 'https://api.github.com/repos/kennethreitz/requests/branches{/branch}', 'tags_url': 'https://api.github.com/repos/kennethreitz/requests/tags', 'blobs_url': 'https://api.github.com/repos/kennethreitz/requests/git/blobs{/sha}', 'git_tags_url': 'https://api.github.com/repos/kennethreitz/requests/git/tags{/sha}', 'git_refs_url': 'https://api.github.com/repos/kennethreitz/requests/git/refs{/sha}', 'trees_url': 'https://api.github.com/repos/kennethreitz/requests/git/trees{/sha}', 'statuses_url': 'https://api.github.com/repos/kennethreitz/requests/statuses/{sha}', 'languages_url': 'https://api.github.com/repos/kennethreitz/requests/languages', 'stargazers_url': 'https://api.github.com/repos/kennethreitz/requests/stargazers', 'contributors_url': 'https://api.github.com/repos/kennethreitz/requests/contributors', 'subscribers_url': 'https://api.github.com/repos/kennethreitz/requests/subscribers', 'subscription_url': 'https://api.github.com/repos/kennethreitz/requests/subscription', 'commits_url': 'https://api.github.com/repos/kennethreitz/requests/commits{/sha}', 'git_commits_url': 'https://api.github.com/repos/kennethreitz/requests/git/commits{/sha}', 'comments_url': 'https://api.github.com/repos/kennethreitz/requests/comments{/number}', 'issue_comment_url': 'https://api.github.com/repos/kennethreitz/requests/issues/comments{/number}', 'contents_url': 'https://api.github.com/repos/kennethreitz/requests/contents/{+path}', 'compare_url': 'https://api.github.com/repos/kennethreitz/requests/compare/{base}...{head}', 'merges_url': 'https://api.github.com/repos/kennethreitz/requests/merges', 'archive_url': 'https://api.github.com/repos/kennethreitz/requests/{archive_format}{/ref}', 'downloads_url': 'https://api.github.com/repos/kennethreitz/requests/downloads', 'issues_url': 'https://api.github.com/repos/kennethreitz/requests/issues{/number}', 'pulls_url': 'https://api.github.com/repos/kennethreitz ...

# %% [markdown]
# ## To print the json in readable format

# %%
import json
print(json.dumps(json_resp, indent=4, sort_keys=True))
# Out:
# {
#     "incomplete_results": false,
#     "items": [
#         {
#             "archive_url": "https://api.github.com/repos/kennethreitz/requests/{archive_format}{/ref}",
#             "archived": false,
#             "assignees_url": "https://api.github.com/repos/kennethreitz/requests/assignees{/user}",
#             "blobs_url": "https://api.github.com/repos/kennethreitz/requests/git/blobs{/sha}",
#             "branches_url": "https://api.github.com/repos/kennethreitz/requests/branches{/branch}",
#             "clone_url": "https://github.com/kennethreitz/requests.git",
#             "collaborators_url": "https://api.github.com/repos/kennethreitz/requests/collaborators{/collaborator}",
#             "comments_url": "https://api.github.com/repos/kennethreitz/requests/comments{/number}",
#             "commits_url": "https://api.github.com/repos/kennethreitz/requests/commits{/sha}",
#             "compare_url": "https://api.github.com/repos/kennethreitz/requests/compare/{base}...{head}",
#             "contents_url": "https://api.github.com/repos/kennethreitz/requests/contents/{+path}",
#             "contributors_url": "https://api.github.com/repos/kennethreitz/requests/contributors",
#             "created_at": "2011-02-13T18:38:17Z",
#             "default_branch": "master",
#             "deployments_url": "https://api.github.com/repos/kennethreitz/requests/deployments",
#             "description": "Python HTTP Requests for Humans\u2122 \u2728\ud83c\udf70\u2728",
#             "downloads_url": "https://api.github.com/repos/kennethreitz/requests/downloads",
#             "events_url": "https://api.github.com/repos/kennethreitz/requests/events",
#             "fork": false,
#             "forks": 6838,
#             "forks_count": 6838,
#             "forks_url": "https://api.github.com/repos/kennethreitz/requests/forks",
#             "full_name": "kennethreitz/requests",
#             "git_commits_url": "https://api.github.com/repos/kennethreitz/requests/git/commits{/sha}",
#             "git_refs_url": "https://api.github.com/repos/kennethreitz/requests/git/refs{/sha}",
#             "git_tags_url": "https://api.github.com/repos/kennethreitz/requests/git/tags{/sha}",
#             "git_url": "git://github.com/kennethreitz/requests.git",
#             "has_downloads": true,
#             "has_issues": true,
#             "has_pages": false,
#             "has_projects": false,
#             "has_wiki": true,
#             "homepage": "http://python-requests.org",
#             "hooks_url": "https://api.github.com/repos/kennethreitz/requests/hooks",
#             "html_url": "https://github.com/kennethreitz/requests",
#             "id": 1362490,
#             "issue_comment_url": "https://api.github.com/repos/kennethreitz/requests/issues/comments{/number}",
#             "issue_events_url": "https://api.github.com/repos/kennethreitz/requests/issues/events{/number}",
#             "issues_url": "https://api.github.com/repos/kennethreitz/requests/issues{/number}",
#             "keys_url": "https://api.github.com/repos/kennethreitz/requests/keys{/key_id}",
#             "labels_url": "https://api.github.com/repos/kennethreitz/requests/labels{/name}",
#             "language": "Python",
#             "languages_url": "https://api.github.com/repos/kennethreitz/requests/languages",
#             "license": {
#                 "key": "other",
#                 "name": "Other",
#                 "node_id": "MDc6TGljZW5zZTA=",
#                 "spdx_id": "NOASSERTION",
#                 "url": null
#             },
#             "merges_url": "https://api.github.com/repos/kennethreitz/requests/merges",
#             "milestones_url": "https://api.github.com/repos/kennethreitz/requests/milestones{/number}",
#             "mirror_url": null,
#             "name": "requests",
#             "node_id": "MDEwOlJlcG9zaXRvcnkxMzYyNDkw",
#             "notifications_url": "https://api.github.com/repos/kennethreitz/requests/notifications{?since,all,participating}",
#             "open_issues": 174,
#             "open_issues_count": 174,
#             "owner": {
#                 "avatar_url": "https://avatars1.githubusercontent.com/u/47496974?v=4",
#                 "events_url": "https://api.github.com/users/kennethreitz/events{/privacy}",
#                 "followers_url": "https://api.github.com/users/kennethreitz/followers",
#                 "following_url": "https://api.github.com/users/kennethreitz/following{/other_user}",
#                 "gists_url": "https://api.github.com/users/kennethreitz/gists{/gist_id}",
#                 "gravatar_id": "",
#                 "html_url": "https://github.com/kennethreitz",
#                 "id": 47496974,
#                 "login": "kennethreitz",
#                 "node_id": "MDEyOk9yZ2FuaXphdGlvbjQ3NDk2OTc0",
#                 "organizations_url": "https://api.github.com/users/kennethreitz/orgs",
#                 "received_events_url": "https://api.github.com/users/kennethreitz/received_events",
#                 "repos_url": "https://api.github.com/users/kennethreitz/repos",
#                 "site_admin": false,
#                 "starred_url": "https://api.github.com/users/kennethreitz/starred{/owner}{/repo}",
#                 "subscriptions_url": "https://api.github.com/users/kennethreitz/subscriptions",
#                 "type": "Organization",
#                 "url": "https://api.github.com/users/kennethreitz"
#             },
#             "private": false,
#             "pulls_url": "https://api.github.com/repos/kennethreitz/requests/pulls{/number}",
#             "pushed_at": "2019-03-10T15:08:29Z",
#             "releases_url": "https://api.github.com/repos/kennethreitz/requests/releases{/id}",
#             "score": 126.23322,
#             "size": 9943,
#             "ssh_url": "git@github.com:kennethreitz/requests.git",
#             "stargazers_count": 37594,
#             "stargazers_url": "https://api.github.com/repos/kennethreitz/requests/stargazers",
#             "statuses_url": "https://api.github.com/repos/kennethreitz/requests/statuses/{sha}",
#             "subscribers_url": "https://api.github.com/repos/kennethreitz/requests/subscribers",
#             "subscription_url": "https://api.github.com/repos/kennethreitz/requests/subscription",
#             "svn_url": "https://github.com/kennethreitz/requests",
#             "tags_url": "https://api.github.com/repos/kennethreitz/requests/tags",
#             "teams_url": "https://api.github.com/repos/kennethreitz/requests/teams",
#             "trees_url": "https://api.github.com/repos/kennethreitz/requests/git/trees{/sha}",
#             "updated_at": "2019-03-12T16:47:19Z",
#             "url": "https://api.github.com/repos/kennethreitz/requests",
#             "watchers": 37594,
#             "watchers_count": 37594
#         },
#         {
#             "archive_url": "https://api.github.com/repos/kennethreitz/grequests/{archive_format}{/ref}",
#             "archived": false,
#             "assignees_url": "https://api.github.com/repos/kennethreitz/grequests/assignees{/user}",
#             "blobs_url": "https://api.github.com/repos/kennethreitz/grequests/git/blobs{/sha}",
#             "branches_url": "https://api.github.com/repos/kennethreitz/grequests/branches{/branch}",
#             "clone_url": "https://github.com/kennethreitz/grequests.git",
#             "collaborators_url": "https://api.github.com/repos/kennethreitz/grequests/collaborators{/collaborator}",
#             "comments_url": "https://api.github.com/repos/kennethreitz/grequests/comments{/number}",
#             "commits_url": "https://api.github.com/repos/kennethreitz/grequests/commits{/sha}",
#             "compare_url": "https://api.github.com/repos/kennethreitz/grequests/compare/{base}...{head}",
#             "contents_url": "https://api.github.com/repos/kennethreitz/grequests/contents/{+path}",
#             "contributors_url": "https://api.github.com/repos/kennethreitz/grequests/contributors",
#             "created_at": "2012-05-10T21:50:15Z",
#             "default_branch": "master",
#             "deployments_url": "https://api.github.com/repos/kennethreitz/grequests/deployments",
#             "description": "Requests + Gevent = <3",
#             "downloads_url": "https://api.github.com/repos/kennethreitz/grequests/downloads",
#             "events_url": "https://api.github.com/repos/kennethreitz/grequests/events",
#             "fork": false,
#             "forks": 284,
#             "forks_count": 284,
#             "forks_url": "https://api.github.com/repos/kennethreitz/grequests/forks",
#             "full_name": "kennethreitz/grequests",
#             "git_commits_url": "https://api.github.com/repos/kennethreitz/grequests/git/commits{/sha}",
#             "git_refs_url": "https://api.github.com/repos/kennethreitz/grequests/git/refs{/sha}",
#             "git_tags_url": "https://api.github.com/repos/kennethreitz/grequests/git/tags{/sha}",
#             "git_url": "git://github.com/kennethreitz/grequests.git",
#             "has_downloads": true,
#             "has_issues": false,
#             "has_pages": false,
#             "has_projects": false,
#             "has_wiki": true,
#             "homepage": "https://pypi.python.org/pypi/grequests",
#             "hooks_url": "https://api.github.com/repos/kennethreitz/grequests/hooks",
#             "html_url": "https://github.com/kennethreitz/grequests",
#             "id": 4290214,
#             "issue_comment_url": "https://api.github.com/repos/kennethreitz/grequests/issues/comments{/number}",
#             "issue_events_url": "https://api.github.com/repos/kennethreitz/grequests/issues/events{/number}",
#             "issues_url": "https://api.github.com/repos/kennethreitz/grequests/issues{/number}",
#             "keys_url": "https://api.github.com/repos/kennethreitz/grequests/keys{/key_id}",
#             "labels_url": "https://api.github.com/repos/kennethreitz/grequests/labels{/name}",
#             "language": "Python",
#             "languages_url": "https://api.github.com/repos/kennethreitz/grequests/languages",
#             "license": {
#                 "key": "bsd-2-clause",
#                 "name": "BSD 2-Clause \"Simplified\" License",
#                 "node_id": "MDc6TGljZW5zZTQ=",
#                 "spdx_id": "BSD-2-Clause",
#                 "url": "https://api.github.com/licenses/bsd-2-clause"
#             },
#             "merges_url": "https://api.github.com/repos/kennethreitz/grequests/merges",
#             "milestones_url": "https://api.github.com/repos/kennethreitz/grequests/milestones{/number}",
#             "mirror_url": null,
#             "name": "grequests",
#             "node_id": "MDEwOlJlcG9zaXRvcnk0MjkwMjE0",
#             "notifications_url": "https://api.github.com/repos/kennethreitz/grequests/notifications{?since,all,participating}",
#             "open_issues": 17,
#             "open_issues_count": 17,
#             "owner": {
#                 "avatar_url": "https://avatars1.githubusercontent.com/u/47496974?v=4",
#                 "events_url": "https://api.github.com/users/kennethreitz/events{/privacy}",
#                 "followers_url": "https://api.github.com/users/kennethreitz/followers",
#                 "following_url": "https://api.github.com/users/kennethreitz/following{/other_user}",
#                 "gists_url": "https://api.github.com/users/kennethreitz/gists{/gist_id}",
#                 "gravatar_id": "",
#                 "html_url": "https://github.com/kennethreitz",
#                 "id": 47496974,
#                 "login": "kennethreitz",
#                 "node_id": "MDEyOk9yZ2FuaXphdGlvbjQ3NDk2OTc0",
#                 "organizations_url": "https://api.github.com/users/kennethreitz/orgs",
#                 "received_events_url": "https://api.github.com/users/kennethreitz/received_events",
#                 "repos_url": "https://api.github.com/users/kennethreitz/repos",
#                 "site_admin": false,
#                 "starred_url": "https://api.github.com/users/kennethreitz/starred{/owner}{/repo}",
#                 "subscriptions_url": "https://api.github.com/users/kennethreitz/subscriptions",
#                 "type": "Organization",
#                 "url": "https://api.github.com/users/kennethreitz"
#             },
#             "private": false,
#             "pulls_url": "https://api.github.com/repos/kennethreitz/grequests/pulls{/number}",
#             "pushed_at": "2019-03-07T14:59:33Z",
#             "releases_url": "https://api.github.com/repos/kennethreitz/grequests/releases{/id}",
#             "score": 92.32626,
#             "size": 37,
#             "ssh_url": "git@github.com:kennethreitz/grequests.git",
#             "stargazers_count": 2927,
#             "stargazers_url": "https://api.github.com/repos/kennethreitz/grequests/stargazers",
#             "statuses_url": "https://api.github.com/repos/kennethreitz/grequests/statuses/{sha}",
#             "subscribers_url": "https://api.github.com/repos/kennethreitz/grequests/subscribers",
#             "subscription_url": "https://api.github.com/repos/kennethreitz/grequests/subscription",
#             "svn_url": "https://github.com/kennethreitz/grequests",
#             "tags_url": "https://api.github.com/repos/kennethreitz/grequests/tags",
#             "teams_url": "https://api.github.com/repos/kennethreitz/grequests/teams",
#             "trees_url": "https://api.github.com/repos/kennethreitz/grequests/git/trees{/sha}",
#             "updated_at": "2019-03-12T06:12:51Z",
#             "url": "https://api.github.com/repos/kennethreitz/grequests",
#             "watchers": 2927,
#             "watchers_count": 2927
#         },
#         {
#             "archive_url": "https://api.github.com/repos/requests/requests-oauthlib/{archive_format}{/ref}",
#             "archived": false,
#             "assignees_url": "https://api.github.com/repos/requests/requests-oauthlib/assignees{/user}",
#             "blobs_url": "https://api.github.com/repos/requests/requests-oauthlib/git/blobs{/sha}",
#             "branches_url": "https://api.github.com/repos/requests/requests-oauthlib/branches{/branch}",
#             "clone_url": "https://github.com/requests/requests-oauthlib.git",
#             "collaborators_url": "https://api.github.com/repos/requests/requests-oauthlib/collaborators{/collaborator}",
#             "comments_url": "https://api.github.com/repos/requests/requests-oauthlib/comments{/number}",
#             "commits_url": "https://api.github.com/repos/requests/requests-oauthlib/commits{/sha}",
#             "compare_url": "https://api.github.com/repos/requests/requests-oauthlib/compare/{base}...{head}",
#             "contents_url": "https://api.github.com/repos/requests/requests-oauthlib/contents/{+path}",
#             "contributors_url": "https://api.github.com/repos/requests/requests-oauthlib/contributors",
#             "created_at": "2012-11-23T10:19:44Z",
#             "default_branch": "master",
#             "deployments_url": "https://api.github.com/repos/requests/requests-oauthlib/deployments",
#             "description": "OAuthlib support for Python-Requests!",
#             "downloads_url": "https://api.github.com/repos/requests/requests-oauthlib/downloads",
#             "events_url": "https://api.github.com/repos/requests/requests-oauthlib/events",
#             "fork": false,
#             "forks": 284,
#             "forks_count": 284,
#             "forks_url": "https://api.github.com/repos/requests/requests-oauthlib/forks",
#             "full_name": "requests/requests-oauthlib",
#             "git_commits_url": "https://api.github.com/repos/requests/requests-oauthlib/git/commits{/sha}",
#             "git_refs_url": "https://api.github.com/repos/requests/requests-oauthlib/git/refs{/sha}",
#             "git_tags_url": "https://api.github.com/repos/requests/requests-oauthlib/git/tags{/sha}",
#             "git_url": "git://github.com/requests/requests-oauthlib.git",
#             "has_downloads": true,
#             "has_issues": true,
#             "has_pages": false,
#             "has_projects": true,
#             "has_wiki": true,
#             "homepage": "https://requests-oauthlib.readthedocs.org/",
#             "hooks_url": "https://api.github.com/repos/requests/requests-oauthlib/hooks",
#             "html_url": "https://github.com/requests/requests-oauthlib",
#             "id": 6825724,
#             "issue_comment_url": "https://api.github.com/repos/requests/requests-oauthlib/issues/comments{/number}",
#             "issue_events_url": "https://api.github.com/repos/requests/requests-oauthlib/issues/events{/number}",
#             "issues_url": "https://api.github.com/repos/requests/requests-oauthlib/issues{/number}",
#             "keys_url": "https://api.github.com/repos/requests/requests-oauthlib/keys{/key_id}",
#             "labels_url": "https://api.github.com/repos/requests/requests-oauthlib/labels{/name}",
#             "language": "Python",
#             "languages_url": "https://api.github.com/repos/requests/requests-oauthlib/languages",
#             "license": {
#                 "key": "isc",
#                 "name": "ISC License",
#                 "node_id": "MDc6TGljZW5zZTEw",
#                 "spdx_id": "ISC",
#                 "url": "https://api.github.com/licenses/isc"
#             },
#             "merges_url": "https://api.github.com/repos/requests/requests-oauthlib/merges",
#             "milestones_url": "https://api.github.com/repos/requests/requests-oauthlib/milestones{/number}",
#             "mirror_url": null,
#             "name": "requests-oauthlib",
#             "node_id": "MDEwOlJlcG9zaXRvcnk2ODI1NzI0",
#             "notifications_url": "https://api.github.com/repos/requests/requests-oauthlib/notifications{?since,all,participating}",
#             "open_issues": 57,
#             "open_issues_count": 57,
#             "owner": {
#                 "avatar_url": "https://avatars1.githubusercontent.com/u/2805331?v=4",
#                 "events_url": "https://api.github.com/users/requests/events{/privacy}",
#                 "followers_url": "https://api.github.com/users/requests/followers",
#                 "following_url": "https://api.github.com/users/requests/following{/other_user}",
#                 "gists_url": "https://api.github.com/users/requests/gists{/gist_id}",
#                 "gravatar_id": "",
#                 "html_url": "https://github.com/requests",
#                 "id": 2805331,
#                 "login": "requests",
#                 "node_id": "MDEyOk9yZ2FuaXphdGlvbjI4MDUzMzE=",
#                 "organizations_url": "https://api.github.com/users/requests/orgs",
#                 "received_events_url": "https://api.github.com/users/requests/received_events",
#                 "repos_url": "https://api.github.com/users/requests/repos",
#                 "site_admin": false,
#                 "starred_url": "https://api.github.com/users/requests/starred{/owner}{/repo}",
#                 "subscriptions_url": "https://api.github.com/users/requests/subscriptions",
#                 "type": "Organization",
#                 "url": "https://api.github.com/users/requests"
#             },
#             "private": false,
#             "pulls_url": "https://api.github.com/repos/requests/requests-oauthlib/pulls{/number}",
#             "pushed_at": "2019-03-03T09:36:46Z",
#             "releases_url": "https://api.github.com/repos/requests/requests-oauthlib/releases{/id}",
#             "score": 84.69756,
#             "size": 411,
#             "ssh_url": "git@github.com:requests/requests-oauthlib.git",
#             "stargazers_count": 984,
#             "stargazers_url": "https://api.github.com/repos/requests/requests-oauthlib/stargazers",
#             "statuses_url": "https://api.github.com/repos/requests/requests-oauthlib/statuses/{sha}",
#             "subscribers_url": "https://api.github.com/repos/requests/requests-oauthlib/subscribers",
#             "subscription_url": "https://api.github.com/repos/requests/requests-oauthlib/subscription",
#             "svn_url": "https://github.com/requests/requests-oauthlib",
#             "tags_url": "https://api.github.com/repos/requests/requests-oauthlib/tags",
#             "teams_url": "https://api.github.com/repos/requests/requests-oauthlib/teams",
#             "trees_url": "https://api.github.com/repos/requests/requests-oauthlib/git/trees{/sha}",
#             "updated_at": "2019-03-12T06:35:47Z",
#             "url": "https://api.github.com/repos/requests/requests-oauthlib",
#             "watchers": 984,
#             "watchers_count": 984
#         },
#         {
#             "archive_url": "https://api.github.com/repos/buildbot/buildbot/{archive_format}{/ref}",
#             "archived": false,
#             "assignees_url": "https://api.github.com/repos/buildbot/buildbot/assignees{/user}",
#             "blobs_url": "https://api.github.com/repos/buildbot/buildbot/git/blobs{/sha}",
#             "branches_url": "https://api.github.com/repos/buildbot/buildbot/branches{/branch}",
#             "clone_url": "https://github.com/buildbot/buildbot.git",
#             "collaborators_url": "https://api.github.com/repos/buildbot/buildbot/collaborators{/collaborator}",
#             "comments_url": "https://api.github.com/repos/buildbot/buildbot/comments{/number}",
#             "commits_url": "https://api.github.com/repos/buildbot/buildbot/commits{/sha}",
#             "compare_url": "https://api.github.com/repos/buildbot/buildbot/compare/{base}...{head}",
#             "contents_url": "https://api.github.com/repos/buildbot/buildbot/contents/{+path}",
#             "contributors_url": "https://api.github.com/repos/buildbot/buildbot/contributors",
#             "created_at": "2010-07-06T17:56:53Z",
#             "default_branch": "master",
#             "deployments_url": "https://api.github.com/repos/buildbot/buildbot/deployments",
#             "description": "Python-based continuous integration testing framework; your pull requests are more than welcome!",
#             "downloads_url": "https://api.github.com/repos/buildbot/buildbot/downloads",
#             "events_url": "https://api.github.com/repos/buildbot/buildbot/events",
#             "fork": false,
#             "forks": 1328,
#             "forks_count": 1328,
#             "forks_url": "https://api.github.com/repos/buildbot/buildbot/forks",
#             "full_name": "buildbot/buildbot",
#             "git_commits_url": "https://api.github.com/repos/buildbot/buildbot/git/commits{/sha}",
#             "git_refs_url": "https://api.github.com/repos/buildbot/buildbot/git/refs{/sha}",
#             "git_tags_url": "https://api.github.com/repos/buildbot/buildbot/git/tags{/sha}",
#             "git_url": "git://github.com/buildbot/buildbot.git",
#             "has_downloads": true,
#             "has_issues": true,
#             "has_pages": false,
#             "has_projects": true,
#             "has_wiki": true,
#             "homepage": "https://www.buildbot.net",
#             "hooks_url": "https://api.github.com/repos/buildbot/buildbot/hooks",
#             "html_url": "https://github.com/buildbot/buildbot",
#             "id": 760165,
#             "issue_comment_url": "https://api.github.com/repos/buildbot/buildbot/issues/comments{/number}",
#             "issue_events_url": "https://api.github.com/repos/buildbot/buildbot/issues/events{/number}",
#             "issues_url": "https://api.github.com/repos/buildbot/buildbot/issues{/number}",
#             "keys_url": "https://api.github.com/repos/buildbot/buildbot/keys{/key_id}",
#             "labels_url": "https://api.github.com/repos/buildbot/buildbot/labels{/name}",
#             "language": "Python",
#             "languages_url": "https://api.github.com/repos/buildbot/buildbot/languages",
#             "license": {
#                 "key": "gpl-2.0",
#                 "name": "GNU General Public License v2.0",
#                 "node_id": "MDc6TGljZW5zZTg=",
#                 "spdx_id": "GPL-2.0",
#                 "url": "https://api.github.com/licenses/gpl-2.0"
#             },
#             "merges_url": "https://api.github.com/repos/buildbot/buildbot/merges",
#             "milestones_url": "https://api.github.com/repos/buildbot/buildbot/milestones{/number}",
#             "mirror_url": null,
#             "name": "buildbot",
#             "node_id": "MDEwOlJlcG9zaXRvcnk3NjAxNjU=",
#             "notifications_url": "https://api.github.com/repos/buildbot/buildbot/notifications{?since,all,participating}",
#             "open_issues": 501,
#             "open_issues_count": 501,
#             "owner": {
#                 "avatar_url": "https://avatars2.githubusercontent.com/u/324515?v=4",
#                 "events_url": "https://api.github.com/users/buildbot/events{/privacy}",
#                 "followers_url": "https://api.github.com/users/buildbot/followers",
#                 "following_url": "https://api.github.com/users/buildbot/following{/other_user}",
#                 "gists_url": "https://api.github.com/users/buildbot/gists{/gist_id}",
#                 "gravatar_id": "",
#                 "html_url": "https://github.com/buildbot",
#                 "id": 324515,
#                 "login": "buildbot",
#                 "node_id": "MDEyOk9yZ2FuaXphdGlvbjMyNDUxNQ==",
#                 "organizations_url": "https://api.github.com/users/buildbot/orgs",
#                 "received_events_url": "https://api.github.com/users/buildbot/received_events",
#                 "repos_url": "https://api.github.com/users/buildbot/repos",
#                 "site_admin": false,
#                 "starred_url": "https://api.github.com/users/buildbot/starred{/owner}{/repo}",
#                 "subscriptions_url": "https://api.github.com/users/buildbot/subscriptions",
#                 "type": "Organization",
#                 "url": "https://api.github.com/users/buildbot"
#             },
#             "private": false,
#             "pulls_url": "https://api.github.com/repos/buildbot/buildbot/pulls{/number}",
#             "pushed_at": "2019-03-12T18:29:28Z",
#             "releases_url": "https://api.github.com/repos/buildbot/buildbot/releases{/id}",
#             "score": 77.60949,
#             "size": 49910,
#             "ssh_url": "git@github.com:buildbot/buildbot.git",
#             "stargazers_count": 3828,
#             "stargazers_url": "https://api.github.com/repos/buildbot/buildbot/stargazers",
#             "statuses_url": "https://api.github.com/repos/buildbot/buildbot/statuses/{sha}",
#             "subscribers_url": "https://api.github.com/repos/buildbot/buildbot/subscribers",
#             "subscription_url": "https://api.github.com/repos/buildbot/buildbot/subscription",
#             "svn_url": "https://github.com/buildbot/buildbot",
#             "tags_url": "https://api.github.com/repos/buildbot/buildbot/tags",
#             "teams_url": "https://api.github.com/repos/buildbot/buildbot/teams",
#             "trees_url": "https://api.github.com/repos/buildbot/buildbot/git/trees{/sha}",
#             "updated_at": "2019-03-12T17:05:26Z",
#             "url": "https://api.github.com/repos/buildbot/buildbot",
#             "watchers": 3828,
#             "watchers_count": 3828
#         },
#         {
#             "archive_url": "https://api.github.com/repos/mvantellingen/python-zeep/{archive_format}{/ref}",
#             "archived": false,
#             "assignees_url": "https://api.github.com/repos/mvantellingen/python-zeep/assignees{/user}",
#             "blobs_url": "https://api.github.com/repos/mvantellingen/python-zeep/git/blobs{/sha}",
#             "branches_url": "https://api.github.com/repos/mvantellingen/python-zeep/branches{/branch}",
#             "clone_url": "https://github.com/mvantellingen/python-zeep.git",
#             "collaborators_url": "https://api.github.com/repos/mvantellingen/python-zeep/collaborators{/collaborator}",
#             "comments_url": "https://api.github.com/repos/mvantellingen/python-zeep/comments{/number}",
#             "commits_url": "https://api.github.com/repos/mvantellingen/python-zeep/commits{/sha}",
#             "compare_url": "https://api.github.com/repos/mvantellingen/python-zeep/compare/{base}...{head}",
#             "contents_url": "https://api.github.com/repos/mvantellingen/python-zeep/contents/{+path}",
#             "contributors_url": "https://api.github.com/repos/mvantellingen/python-zeep/contributors",
#             "created_at": "2016-02-14T10:31:07Z",
#             "default_branch": "master",
#             "deployments_url": "https://api.github.com/repos/mvantellingen/python-zeep/deployments",
#             "description": "A modern/fast python SOAP client based on lxml / requests",
#             "downloads_url": "https://api.github.com/repos/mvantellingen/python-zeep/downloads",
#             "events_url": "https://api.github.com/repos/mvantellingen/python-zeep/events",
#             "fork": false,
#             "forks": 365,
#             "forks_count": 365,
#             "forks_url": "https://api.github.com/repos/mvantellingen/python-zeep/forks",
#             "full_name": "mvantellingen/python-zeep",
#             "git_commits_url": "https://api.github.com/repos/mvantellingen/python-zeep/git/commits{/sha}",
#             "git_refs_url": "https://api.github.com/repos/mvantellingen/python-zeep/git/refs{/sha}",
#             "git_tags_url": "https://api.github.com/repos/mvantellingen/python-zeep/git/tags{/sha}",
#             "git_url": "git://github.com/mvantellingen/python-zeep.git",
#             "has_downloads": true,
#             "has_issues": true,
#             "has_pages": false,
#             "has_projects": true,
#             "has_wiki": true,
#             "homepage": "http://docs.python-zeep.org",
#             "hooks_url": "https://api.github.com/repos/mvantellingen/python-zeep/hooks",
#             "html_url": "https://github.com/mvantellingen/python-zeep",
#             "id": 51690353,
#             "issue_comment_url": "https://api.github.com/repos/mvantellingen/python-zeep/issues/comments{/number}",
#             "issue_events_url": "https://api.github.com/repos/mvantellingen/python-zeep/issues/events{/number}",
#             "issues_url": "https://api.github.com/repos/mvantellingen/python-zeep/issues{/number}",
#             "keys_url": "https://api.github.com/repos/mvantellingen/python-zeep/keys{/key_id}",
#             "labels_url": "https://api.github.com/repos/mvantellingen/python-zeep/labels{/name}",
#             "language": "Python",
#             "languages_url": "https://api.github.com/repos/mvantellingen/python-zeep/languages",
#             "license": {
#                 "key": "other",
#                 "name": "Other",
#                 "node_id": "MDc6TGljZW5zZTA=",
#                 "spdx_id": "NOASSERTION",
#                 "url": null
#             },
#             "merges_url": "https://api.github.com/repos/mvantellingen/python-zeep/merges",
#             "milestones_url": "https://api.github.com/repos/mvantellingen/python-zeep/milestones{/number}",
#             "mirror_url": null,
#             "name": "python-zeep",
#             "node_id": "MDEwOlJlcG9zaXRvcnk1MTY5MDM1Mw==",
#             "notifications_url": "https://api.github.com/repos/mvantellingen/python-zeep/notifications{?since,all,participating}",
#             "open_issues": 179,
#             "open_issues_count": 179,
#             "owner": {
#                 "avatar_url": "https://avatars3.githubusercontent.com/u/245297?v=4",
#                 "events_url": "https://api.github.com/users/mvantellingen/events{/privacy}",
#                 "followers_url": "https://api.github.com/users/mvantellingen/followers",
#                 "following_url": "https://api.github.com/users/mvantellingen/following{/other_user}",
#                 "gists_url": "https://api.github.com/users/mvantellingen/gists{/gist_id}",
#                 "gravatar_id": "",
#                 "html_url": "https://github.com/mvantellingen",
#                 "id": 245297,
#                 "login": "mvantellingen",
#                 "node_id": "MDQ6VXNlcjI0NTI5Nw==",
#                 "organizations_url": "https://api.github.com/users/mvantellingen/orgs",
#                 "received_events_url": "https://api.github.com/users/mvantellingen/received_events",
#                 "repos_url": "https://api.github.com/users/mvantellingen/repos",
#                 "site_admin": false,
#                 "starred_url": "https://api.github.com/users/mvantellingen/starred{/owner}{/repo}",
#                 "subscriptions_url": "https://api.github.com/users/mvantellingen/subscriptions",
#                 "type": "User",
#                 "url": "https://api.github.com/users/mvantellingen"
#             },
#             "private": false,
#             "pulls_url": "https://api.github.com/repos/mvantellingen/python-zeep/pulls{/number}",
#             "pushed_at": "2019-03-11T10:41:52Z",
#             "releases_url": "https://api.github.com/repos/mvantellingen/python-zeep/releases{/id}",
#             "score": 75.642876,
#             "size": 2366,
#             "ssh_url": "git@github.com:mvantellingen/python-zeep.git",
#             "stargazers_count": 1110,
#             "stargazers_url": "https://api.github.com/repos/mvantellingen/python-zeep/stargazers",
#             "statuses_url": "https://api.github.com/repos/mvantellingen/python-zeep/statuses/{sha}",
#             "subscribers_url": "https://api.github.com/repos/mvantellingen/python-zeep/subscribers",
#             "subscription_url": "https://api.github.com/repos/mvantellingen/python-zeep/subscription",
#             "svn_url": "https://github.com/mvantellingen/python-zeep",
#             "tags_url": "https://api.github.com/repos/mvantellingen/python-zeep/tags",
#             "teams_url": "https://api.github.com/repos/mvantellingen/python-zeep/teams",
#             "trees_url": "https://api.github.com/repos/mvantellingen/python-zeep/git/trees{/sha}",
#             "updated_at": "2019-03-12T14:47:11Z",
#             "url": "https://api.github.com/repos/mvantellingen/python-zeep",
#             "watchers": 1110,
#             "watchers_count": 1110
#         },
#         {
#             "archive_url": "https://api.github.com/repos/SpiderClub/weibospider/{archive_format}{/ref}",
#             "archived": false,
#             "assignees_url": "https://api.github.com/repos/SpiderClub/weibospider/assignees{/user}",
#             "blobs_url": "https://api.github.com/repos/SpiderClub/weibospider/git/blobs{/sha}",
#             "branches_url": "https://api.github.com/repos/SpiderClub/weibospider/branches{/branch}",
#             "clone_url": "https://github.com/SpiderClub/weibospider.git",
#             "collaborators_url": "https://api.github.com/repos/SpiderClub/weibospider/collaborators{/collaborator}",
#             "comments_url": "https://api.github.com/repos/SpiderClub/weibospider/comments{/number}",
#             "commits_url": "https://api.github.com/repos/SpiderClub/weibospider/commits{/sha}",
#             "compare_url": "https://api.github.com/repos/SpiderClub/weibospider/compare/{base}...{head}",
#             "contents_url": "https://api.github.com/repos/SpiderClub/weibospider/contents/{+path}",
#             "contributors_url": "https://api.github.com/repos/SpiderClub/weibospider/contributors",
#             "created_at": "2016-06-27T07:02:06Z",
#             "default_branch": "master",
#             "deployments_url": "https://api.github.com/repos/SpiderClub/weibospider/deployments",
#             "description": ":zap: A distributed crawler for weibo, building with celery and requests.",
#             "downloads_url": "https://api.github.com/repos/SpiderClub/weibospider/downloads",
#             "events_url": "https://api.github.com/repos/SpiderClub/weibospider/events",
#             "fork": false,
#             "forks": 952,
#             "forks_count": 952,
#             "forks_url": "https://api.github.com/repos/SpiderClub/weibospider/forks",
#             "full_name": "SpiderClub/weibospider",
#             "git_commits_url": "https://api.github.com/repos/SpiderClub/weibospider/git/commits{/sha}",
#             "git_refs_url": "https://api.github.com/repos/SpiderClub/weibospider/git/refs{/sha}",
#             "git_tags_url": "https://api.github.com/repos/SpiderClub/weibospider/git/tags{/sha}",
#             "git_url": "git://github.com/SpiderClub/weibospider.git",
#             "has_downloads": true,
#             "has_issues": true,
#             "has_pages": true,
#             "has_projects": true,
#             "has_wiki": true,
#             "homepage": "",
#             "hooks_url": "https://api.github.com/repos/SpiderClub/weibospider/hooks",
#             "html_url": "https://github.com/SpiderClub/weibospider",
#             "id": 62032720,
#             "issue_comment_url": "https://api.github.com/repos/SpiderClub/weibospider/issues/comments{/number}",
#             "issue_events_url": "https://api.github.com/repos/SpiderClub/weibospider/issues/events{/number}",
#             "issues_url": "https://api.github.com/repos/SpiderClub/weibospider/issues{/number}",
#             "keys_url": "https://api.github.com/repos/SpiderClub/weibospider/keys{/key_id}",
#             "labels_url": "https://api.github.com/repos/SpiderClub/weibospider/labels{/name}",
#             "language": "Python",
#             "languages_url": "https://api.github.com/repos/SpiderClub/weibospider/languages",
#             "license": {
#                 "key": "mit",
#                 "name": "MIT License",
#                 "node_id": "MDc6TGljZW5zZTEz",
#                 "spdx_id": "MIT",
#                 "url": "https://api.github.com/licenses/mit"
#             },
#             "merges_url": "https://api.github.com/repos/SpiderClub/weibospider/merges",
#             "milestones_url": "https://api.github.com/repos/SpiderClub/weibospider/milestones{/number}",
#             "mirror_url": null,
#             "name": "weibospider",
#             "node_id": "MDEwOlJlcG9zaXRvcnk2MjAzMjcyMA==",
#             "notifications_url": "https://api.github.com/repos/SpiderClub/weibospider/notifications{?since,all,participating}",
#             "open_issues": 7,
#             "open_issues_count": 7,
#             "owner": {
#                 "avatar_url": "https://avatars1.githubusercontent.com/u/32793535?v=4",
#                 "events_url": "https://api.github.com/users/SpiderClub/events{/privacy}",
#                 "followers_url": "https://api.github.com/users/SpiderClub/followers",
#                 "following_url": "https://api.github.com/users/SpiderClub/following{/other_user}",
#                 "gists_url": "https://api.github.com/users/SpiderClub/gists{/gist_id}",
#                 "gravatar_id": "",
#                 "html_url": "https://github.com/SpiderClub",
#                 "id": 32793535,
#                 "login": "SpiderClub",
#                 "node_id": "MDEyOk9yZ2FuaXphdGlvbjMyNzkzNTM1",
#                 "organizations_url": "https://api.github.com/users/SpiderClub/orgs",
#                 "received_events_url": "https://api.github.com/users/SpiderClub/received_events",
#                 "repos_url": "https://api.github.com/users/SpiderClub/repos",
#                 "site_admin": false,
#                 "starred_url": "https://api.github.com/users/SpiderClub/starred{/owner}{/repo}",
#                 "subscriptions_url": "https://api.github.com/users/SpiderClub/subscriptions",
#                 "type": "Organization",
#                 "url": "https://api.github.com/users/SpiderClub"
#             },
#             "private": false,
#             "pulls_url": "https://api.github.com/repos/SpiderClub/weibospider/pulls{/number}",
#             "pushed_at": "2019-03-01T08:18:33Z",
#             "releases_url": "https://api.github.com/repos/SpiderClub/weibospider/releases{/id}",
#             "score": 75.16043,
#             "size": 77519,
#             "ssh_url": "git@github.com:SpiderClub/weibospider.git",
#             "stargazers_count": 3383,
#             "stargazers_url": "https://api.github.com/repos/SpiderClub/weibospider/stargazers",
#             "statuses_url": "https://api.github.com/repos/SpiderClub/weibospider/statuses/{sha}",
#             "subscribers_url": "https://api.github.com/repos/SpiderClub/weibospider/subscribers",
#             "subscription_url": "https://api.github.com/repos/SpiderClub/weibospider/subscription",
#             "svn_url": "https://github.com/SpiderClub/weibospider",
#             "tags_url": "https://api.github.com/repos/SpiderClub/weibospider/tags",
#             "teams_url": "https://api.github.com/repos/SpiderClub/weibospider/teams",
#             "trees_url": "https://api.github.com/repos/SpiderClub/weibospider/git/trees{/sha}",
#             "updated_at": "2019-03-12T12:53:38Z",
#             "url": "https://api.github.com/repos/SpiderClub/weibospider",
#             "watchers": 3383,
#             "watchers_count": 3383
#         },
#         {
#             "archive_url": "https://api.github.com/repos/getsentry/responses/{archive_format}{/ref}",
#             "archived": false,
#             "assignees_url": "https://api.github.com/repos/getsentry/responses/assignees{/user}",
#             "blobs_url": "https://api.github.com/repos/getsentry/responses/git/blobs{/sha}",
#             "branches_url": "https://api.github.com/repos/getsentry/responses/branches{/branch}",
#             "clone_url": "https://github.com/getsentry/responses.git",
#             "collaborators_url": "https://api.github.com/repos/getsentry/responses/collaborators{/collaborator}",
#             "comments_url": "https://api.github.com/repos/getsentry/responses/comments{/number}",
#             "commits_url": "https://api.github.com/repos/getsentry/responses/commits{/sha}",
#             "compare_url": "https://api.github.com/repos/getsentry/responses/compare/{base}...{head}",
#             "contents_url": "https://api.github.com/repos/getsentry/responses/contents/{+path}",
#             "contributors_url": "https://api.github.com/repos/getsentry/responses/contributors",
#             "created_at": "2013-11-15T23:28:18Z",
#             "default_branch": "master",
#             "deployments_url": "https://api.github.com/repos/getsentry/responses/deployments",
#             "description": "A utility for mocking out the Python Requests library.",
#             "downloads_url": "https://api.github.com/repos/getsentry/responses/downloads",
#             "events_url": "https://api.github.com/repos/getsentry/responses/events",
#             "fork": false,
#             "forks": 205,
#             "forks_count": 205,
#             "forks_url": "https://api.github.com/repos/getsentry/responses/forks",
#             "full_name": "getsentry/responses",
#             "git_commits_url": "https://api.github.com/repos/getsentry/responses/git/commits{/sha}",
#             "git_refs_url": "https://api.github.com/repos/getsentry/responses/git/refs{/sha}",
#             "git_tags_url": "https://api.github.com/repos/getsentry/responses/git/tags{/sha}",
#             "git_url": "git://github.com/getsentry/responses.git",
#             "has_downloads": true,
#             "has_issues": true,
#             "has_pages": false,
#             "has_projects": true,
#             "has_wiki": false,
#             "homepage": "",
#             "hooks_url": "https://api.github.com/repos/getsentry/responses/hooks",
#             "html_url": "https://github.com/getsentry/responses",
#             "id": 14437755,
#             "issue_comment_url": "https://api.github.com/repos/getsentry/responses/issues/comments{/number}",
#             "issue_events_url": "https://api.github.com/repos/getsentry/responses/issues/events{/number}",
#             "issues_url": "https://api.github.com/repos/getsentry/responses/issues{/number}",
#             "keys_url": "https://api.github.com/repos/getsentry/responses/keys{/key_id}",
#             "labels_url": "https://api.github.com/repos/getsentry/responses/labels{/name}",
#             "language": "Python",
#             "languages_url": "https://api.github.com/repos/getsentry/responses/languages",
#             "license": {
#                 "key": "apache-2.0",
#                 "name": "Apache License 2.0",
#                 "node_id": "MDc6TGljZW5zZTI=",
#                 "spdx_id": "Apache-2.0",
#                 "url": "https://api.github.com/licenses/apache-2.0"
#             },
#             "merges_url": "https://api.github.com/repos/getsentry/responses/merges",
#             "milestones_url": "https://api.github.com/repos/getsentry/responses/milestones{/number}",
#             "mirror_url": null,
#             "name": "responses",
#             "node_id": "MDEwOlJlcG9zaXRvcnkxNDQzNzc1NQ==",
#             "notifications_url": "https://api.github.com/repos/getsentry/responses/notifications{?since,all,participating}",
#             "open_issues": 64,
#             "open_issues_count": 64,
#             "owner": {
#                 "avatar_url": "https://avatars0.githubusercontent.com/u/1396951?v=4",
#                 "events_url": "https://api.github.com/users/getsentry/events{/privacy}",
#                 "followers_url": "https://api.github.com/users/getsentry/followers",
#                 "following_url": "https://api.github.com/users/getsentry/following{/other_user}",
#                 "gists_url": "https://api.github.com/users/getsentry/gists{/gist_id}",
#                 "gravatar_id": "",
#                 "html_url": "https://github.com/getsentry",
#                 "id": 1396951,
#                 "login": "getsentry",
#                 "node_id": "MDEyOk9yZ2FuaXphdGlvbjEzOTY5NTE=",
#                 "organizations_url": "https://api.github.com/users/getsentry/orgs",
#                 "received_events_url": "https://api.github.com/users/getsentry/received_events",
#                 "repos_url": "https://api.github.com/users/getsentry/repos",
#                 "site_admin": false,
#                 "starred_url": "https://api.github.com/users/getsentry/starred{/owner}{/repo}",
#                 "subscriptions_url": "https://api.github.com/users/getsentry/subscriptions",
#                 "type": "Organization",
#                 "url": "https://api.github.com/users/getsentry"
#             },
#             "private": false,
#             "pulls_url": "https://api.github.com/repos/getsentry/responses/pulls{/number}",
#             "pushed_at": "2019-03-11T01:11:22Z",
#             "releases_url": "https://api.github.com/repos/getsentry/responses/releases{/id}",
#             "score": 73.38962,
#             "size": 262,
#             "ssh_url": "git@github.com:getsentry/responses.git",
#             "stargazers_count": 2247,
#             "stargazers_url": "https://api.github.com/repos/getsentry/responses/stargazers",
#             "statuses_url": "https://api.github.com/repos/getsentry/responses/statuses/{sha}",
#             "subscribers_url": "https://api.github.com/repos/getsentry/responses/subscribers",
#             "subscription_url": "https://api.github.com/repos/getsentry/responses/subscription",
#             "svn_url": "https://github.com/getsentry/responses",
#             "tags_url": "https://api.github.com/repos/getsentry/responses/tags",
#             "teams_url": "https://api.github.com/repos/getsentry/responses/teams",
#             "trees_url": "https://api.github.com/repos/getsentry/responses/git/trees{/sha}",
#             "updated_at": "2019-03-12T00:45:53Z",
#             "url": "https://api.github.com/repos/getsentry/responses",
#             "watchers": 2247,
#             "watchers_count": 2247
#         },
#         {
#             "archive_url": "https://api.github.com/repos/SirVer/ultisnips/{archive_format}{/ref}",
#             "archived": false,
#             "assignees_url": "https://api.github.com/repos/SirVer/ultisnips/assignees{/user}",
#             "blobs_url": "https://api.github.com/repos/SirVer/ultisnips/git/blobs{/sha}",
#             "branches_url": "https://api.github.com/repos/SirVer/ultisnips/branches{/branch}",
#             "clone_url": "https://github.com/SirVer/ultisnips.git",
#             "collaborators_url": "https://api.github.com/repos/SirVer/ultisnips/collaborators{/collaborator}",
#             "comments_url": "https://api.github.com/repos/SirVer/ultisnips/comments{/number}",
#             "commits_url": "https://api.github.com/repos/SirVer/ultisnips/commits{/sha}",
#             "compare_url": "https://api.github.com/repos/SirVer/ultisnips/compare/{base}...{head}",
#             "contents_url": "https://api.github.com/repos/SirVer/ultisnips/contents/{+path}",
#             "contributors_url": "https://api.github.com/repos/SirVer/ultisnips/contributors",
#             "created_at": "2011-12-30T07:07:24Z",
#             "default_branch": "master",
#             "deployments_url": "https://api.github.com/repos/SirVer/ultisnips/deployments",
#             "description": "UltiSnips - The ultimate snippet solution for Vim. Send pull requests to SirVer/ultisnips!",
# ...
#             "milestones_url": "https://api.github.com/repos/smore-inc/tinys3/milestones{/number}",
#             "mirror_url": null,
#             "name": "tinys3",
#             "node_id": "MDEwOlJlcG9zaXRvcnk5MTA5NDA4",
#             "notifications_url": "https://api.github.com/repos/smore-inc/tinys3/notifications{?since,all,participating}",
#             "open_issues": 38,
#             "open_issues_count": 38,
#             "owner": {
#                 "avatar_url": "https://avatars3.githubusercontent.com/u/1774248?v=4",
#                 "events_url": "https://api.github.com/users/smore-inc/events{/privacy}",
#                 "followers_url": "https://api.github.com/users/smore-inc/followers",
#                 "following_url": "https://api.github.com/users/smore-inc/following{/other_user}",
#                 "gists_url": "https://api.github.com/users/smore-inc/gists{/gist_id}",
#                 "gravatar_id": "",
#                 "html_url": "https://github.com/smore-inc",
#                 "id": 1774248,
#                 "login": "smore-inc",
#                 "node_id": "MDEyOk9yZ2FuaXphdGlvbjE3NzQyNDg=",
#                 "organizations_url": "https://api.github.com/users/smore-inc/orgs",
#                 "received_events_url": "https://api.github.com/users/smore-inc/received_events",
#                 "repos_url": "https://api.github.com/users/smore-inc/repos",
#                 "site_admin": false,
#                 "starred_url": "https://api.github.com/users/smore-inc/starred{/owner}{/repo}",
#                 "subscriptions_url": "https://api.github.com/users/smore-inc/subscriptions",
#                 "type": "Organization",
#                 "url": "https://api.github.com/users/smore-inc"
#             },
#             "private": false,
#             "pulls_url": "https://api.github.com/repos/smore-inc/tinys3/pulls{/number}",
#             "pushed_at": "2019-01-23T01:20:24Z",
#             "releases_url": "https://api.github.com/repos/smore-inc/tinys3/releases{/id}",
#             "score": 56.265396,
#             "size": 185,
#             "ssh_url": "git@github.com:smore-inc/tinys3.git",
#             "stargazers_count": 260,
#             "stargazers_url": "https://api.github.com/repos/smore-inc/tinys3/stargazers",
#             "statuses_url": "https://api.github.com/repos/smore-inc/tinys3/statuses/{sha}",
#             "subscribers_url": "https://api.github.com/repos/smore-inc/tinys3/subscribers",
#             "subscription_url": "https://api.github.com/repos/smore-inc/tinys3/subscription",
#             "svn_url": "https://github.com/smore-inc/tinys3",
#             "tags_url": "https://api.github.com/repos/smore-inc/tinys3/tags",
#             "teams_url": "https://api.github.com/repos/smore-inc/tinys3/teams",
#             "trees_url": "https://api.github.com/repos/smore-inc/tinys3/git/trees{/sha}",
#             "updated_at": "2019-02-07T16:35:58Z",
#             "url": "https://api.github.com/repos/smore-inc/tinys3",
#             "watchers": 260,
#             "watchers_count": 260
#         },
#         {
#             "archive_url": "https://api.github.com/repos/requests/requests-kerberos/{archive_format}{/ref}",
#             "archived": false,
#             "assignees_url": "https://api.github.com/repos/requests/requests-kerberos/assignees{/user}",
#             "blobs_url": "https://api.github.com/repos/requests/requests-kerberos/git/blobs{/sha}",
#             "branches_url": "https://api.github.com/repos/requests/requests-kerberos/branches{/branch}",
#             "clone_url": "https://github.com/requests/requests-kerberos.git",
#             "collaborators_url": "https://api.github.com/repos/requests/requests-kerberos/collaborators{/collaborator}",
#             "comments_url": "https://api.github.com/repos/requests/requests-kerberos/comments{/number}",
#             "commits_url": "https://api.github.com/repos/requests/requests-kerberos/commits{/sha}",
#             "compare_url": "https://api.github.com/repos/requests/requests-kerberos/compare/{base}...{head}",
#             "contents_url": "https://api.github.com/repos/requests/requests-kerberos/contents/{+path}",
#             "contributors_url": "https://api.github.com/repos/requests/requests-kerberos/contributors",
#             "created_at": "2012-11-15T19:22:30Z",
#             "default_branch": "master",
#             "deployments_url": "https://api.github.com/repos/requests/requests-kerberos/deployments",
#             "description": "An authentication handler for using Kerberos with Python Requests.",
#             "downloads_url": "https://api.github.com/repos/requests/requests-kerberos/downloads",
#             "events_url": "https://api.github.com/repos/requests/requests-kerberos/events",
#             "fork": false,
#             "forks": 68,
#             "forks_count": 68,
#             "forks_url": "https://api.github.com/repos/requests/requests-kerberos/forks",
#             "full_name": "requests/requests-kerberos",
#             "git_commits_url": "https://api.github.com/repos/requests/requests-kerberos/git/commits{/sha}",
#             "git_refs_url": "https://api.github.com/repos/requests/requests-kerberos/git/refs{/sha}",
#             "git_tags_url": "https://api.github.com/repos/requests/requests-kerberos/git/tags{/sha}",
#             "git_url": "git://github.com/requests/requests-kerberos.git",
#             "has_downloads": true,
#             "has_issues": true,
#             "has_pages": false,
#             "has_projects": true,
#             "has_wiki": true,
#             "homepage": null,
#             "hooks_url": "https://api.github.com/repos/requests/requests-kerberos/hooks",
#             "html_url": "https://github.com/requests/requests-kerberos",
#             "id": 6710117,
#             "issue_comment_url": "https://api.github.com/repos/requests/requests-kerberos/issues/comments{/number}",
#             "issue_events_url": "https://api.github.com/repos/requests/requests-kerberos/issues/events{/number}",
#             "issues_url": "https://api.github.com/repos/requests/requests-kerberos/issues{/number}",
#             "keys_url": "https://api.github.com/repos/requests/requests-kerberos/keys{/key_id}",
#             "labels_url": "https://api.github.com/repos/requests/requests-kerberos/labels{/name}",
#             "language": "Python",
#             "languages_url": "https://api.github.com/repos/requests/requests-kerberos/languages",
#             "license": {
#                 "key": "isc",
#                 "name": "ISC License",
#                 "node_id": "MDc6TGljZW5zZTEw",
#                 "spdx_id": "ISC",
#                 "url": "https://api.github.com/licenses/isc"
#             },
#             "merges_url": "https://api.github.com/repos/requests/requests-kerberos/merges",
#             "milestones_url": "https://api.github.com/repos/requests/requests-kerberos/milestones{/number}",
#             "mirror_url": null,
#             "name": "requests-kerberos",
#             "node_id": "MDEwOlJlcG9zaXRvcnk2NzEwMTE3",
#             "notifications_url": "https://api.github.com/repos/requests/requests-kerberos/notifications{?since,all,participating}",
#             "open_issues": 28,
#             "open_issues_count": 28,
#             "owner": {
#                 "avatar_url": "https://avatars1.githubusercontent.com/u/2805331?v=4",
#                 "events_url": "https://api.github.com/users/requests/events{/privacy}",
#                 "followers_url": "https://api.github.com/users/requests/followers",
#                 "following_url": "https://api.github.com/users/requests/following{/other_user}",
#                 "gists_url": "https://api.github.com/users/requests/gists{/gist_id}",
#                 "gravatar_id": "",
#                 "html_url": "https://github.com/requests",
#                 "id": 2805331,
#                 "login": "requests",
#                 "node_id": "MDEyOk9yZ2FuaXphdGlvbjI4MDUzMzE=",
#                 "organizations_url": "https://api.github.com/users/requests/orgs",
#                 "received_events_url": "https://api.github.com/users/requests/received_events",
#                 "repos_url": "https://api.github.com/users/requests/repos",
#                 "site_admin": false,
#                 "starred_url": "https://api.github.com/users/requests/starred{/owner}{/repo}",
#                 "subscriptions_url": "https://api.github.com/users/requests/subscriptions",
#                 "type": "Organization",
#                 "url": "https://api.github.com/users/requests"
#             },
#             "private": false,
#             "pulls_url": "https://api.github.com/repos/requests/requests-kerberos/pulls{/number}",
#             "pushed_at": "2019-02-26T12:16:23Z",
#             "releases_url": "https://api.github.com/repos/requests/requests-kerberos/releases{/id}",
#             "score": 56.159637,
#             "size": 139,
#             "ssh_url": "git@github.com:requests/requests-kerberos.git",
#             "stargazers_count": 153,
#             "stargazers_url": "https://api.github.com/repos/requests/requests-kerberos/stargazers",
#             "statuses_url": "https://api.github.com/repos/requests/requests-kerberos/statuses/{sha}",
#             "subscribers_url": "https://api.github.com/repos/requests/requests-kerberos/subscribers",
#             "subscription_url": "https://api.github.com/repos/requests/requests-kerberos/subscription",
#             "svn_url": "https://github.com/requests/requests-kerberos",
#             "tags_url": "https://api.github.com/repos/requests/requests-kerberos/tags",
#             "teams_url": "https://api.github.com/repos/requests/requests-kerberos/teams",
#             "trees_url": "https://api.github.com/repos/requests/requests-kerberos/git/trees{/sha}",
#             "updated_at": "2019-02-20T20:03:15Z",
#             "url": "https://api.github.com/repos/requests/requests-kerberos",
#             "watchers": 153,
#             "watchers_count": 153
#         },
#         {
#             "archive_url": "https://api.github.com/repos/twisted/treq/{archive_format}{/ref}",
#             "archived": false,
#             "assignees_url": "https://api.github.com/repos/twisted/treq/assignees{/user}",
#             "blobs_url": "https://api.github.com/repos/twisted/treq/git/blobs{/sha}",
#             "branches_url": "https://api.github.com/repos/twisted/treq/branches{/branch}",
#             "clone_url": "https://github.com/twisted/treq.git",
#             "collaborators_url": "https://api.github.com/repos/twisted/treq/collaborators{/collaborator}",
#             "comments_url": "https://api.github.com/repos/twisted/treq/comments{/number}",
#             "commits_url": "https://api.github.com/repos/twisted/treq/commits{/sha}",
#             "compare_url": "https://api.github.com/repos/twisted/treq/compare/{base}...{head}",
#             "contents_url": "https://api.github.com/repos/twisted/treq/contents/{+path}",
#             "contributors_url": "https://api.github.com/repos/twisted/treq/contributors",
#             "created_at": "2012-05-18T18:57:21Z",
#             "default_branch": "master",
#             "deployments_url": "https://api.github.com/repos/twisted/treq/deployments",
#             "description": "Python requests like API built on top of Twisted's HTTP client.",
#             "downloads_url": "https://api.github.com/repos/twisted/treq/downloads",
#             "events_url": "https://api.github.com/repos/twisted/treq/events",
#             "fork": false,
#             "forks": 123,
#             "forks_count": 123,
#             "forks_url": "https://api.github.com/repos/twisted/treq/forks",
#             "full_name": "twisted/treq",
#             "git_commits_url": "https://api.github.com/repos/twisted/treq/git/commits{/sha}",
#             "git_refs_url": "https://api.github.com/repos/twisted/treq/git/refs{/sha}",
#             "git_tags_url": "https://api.github.com/repos/twisted/treq/git/tags{/sha}",
#             "git_url": "git://github.com/twisted/treq.git",
#             "has_downloads": true,
#             "has_issues": true,
#             "has_pages": false,
#             "has_projects": true,
#             "has_wiki": true,
#             "homepage": null,
#             "hooks_url": "https://api.github.com/repos/twisted/treq/hooks",
#             "html_url": "https://github.com/twisted/treq",
#             "id": 4372437,
#             "issue_comment_url": "https://api.github.com/repos/twisted/treq/issues/comments{/number}",
#             "issue_events_url": "https://api.github.com/repos/twisted/treq/issues/events{/number}",
#             "issues_url": "https://api.github.com/repos/twisted/treq/issues{/number}",
#             "keys_url": "https://api.github.com/repos/twisted/treq/keys{/key_id}",
#             "labels_url": "https://api.github.com/repos/twisted/treq/labels{/name}",
#             "language": "Python",
#             "languages_url": "https://api.github.com/repos/twisted/treq/languages",
#             "license": {
#                 "key": "other",
#                 "name": "Other",
#                 "node_id": "MDc6TGljZW5zZTA=",
#                 "spdx_id": "NOASSERTION",
#                 "url": null
#             },
#             "merges_url": "https://api.github.com/repos/twisted/treq/merges",
#             "milestones_url": "https://api.github.com/repos/twisted/treq/milestones{/number}",
#             "mirror_url": null,
#             "name": "treq",
#             "node_id": "MDEwOlJlcG9zaXRvcnk0MzcyNDM3",
#             "notifications_url": "https://api.github.com/repos/twisted/treq/notifications{?since,all,participating}",
#             "open_issues": 50,
#             "open_issues_count": 50,
#             "owner": {
#                 "avatar_url": "https://avatars3.githubusercontent.com/u/716546?v=4",
#                 "events_url": "https://api.github.com/users/twisted/events{/privacy}",
#                 "followers_url": "https://api.github.com/users/twisted/followers",
#                 "following_url": "https://api.github.com/users/twisted/following{/other_user}",
#                 "gists_url": "https://api.github.com/users/twisted/gists{/gist_id}",
#                 "gravatar_id": "",
#                 "html_url": "https://github.com/twisted",
#                 "id": 716546,
#                 "login": "twisted",
#                 "node_id": "MDEyOk9yZ2FuaXphdGlvbjcxNjU0Ng==",
#                 "organizations_url": "https://api.github.com/users/twisted/orgs",
#                 "received_events_url": "https://api.github.com/users/twisted/received_events",
#                 "repos_url": "https://api.github.com/users/twisted/repos",
#                 "site_admin": false,
#                 "starred_url": "https://api.github.com/users/twisted/starred{/owner}{/repo}",
#                 "subscriptions_url": "https://api.github.com/users/twisted/subscriptions",
#                 "type": "Organization",
#                 "url": "https://api.github.com/users/twisted"
#             },
#             "private": false,
#             "pulls_url": "https://api.github.com/repos/twisted/treq/pulls{/number}",
#             "pushed_at": "2019-03-06T06:56:27Z",
#             "releases_url": "https://api.github.com/repos/twisted/treq/releases{/id}",
#             "score": 56.008484,
#             "size": 501,
#             "ssh_url": "git@github.com:twisted/treq.git",
#             "stargazers_count": 455,
#             "stargazers_url": "https://api.github.com/repos/twisted/treq/stargazers",
#             "statuses_url": "https://api.github.com/repos/twisted/treq/statuses/{sha}",
#             "subscribers_url": "https://api.github.com/repos/twisted/treq/subscribers",
#             "subscription_url": "https://api.github.com/repos/twisted/treq/subscription",
#             "svn_url": "https://github.com/twisted/treq",
#             "tags_url": "https://api.github.com/repos/twisted/treq/tags",
#             "teams_url": "https://api.github.com/repos/twisted/treq/teams",
#             "trees_url": "https://api.github.com/repos/twisted/treq/git/trees{/sha}",
#             "updated_at": "2019-03-10T03:58:19Z",
#             "url": "https://api.github.com/repos/twisted/treq",
#             "watchers": 455,
#             "watchers_count": 455
#         }
#     ],
#     "total_count": 7106
# }

# %% [markdown]
# ## Fetch a specific key's value

# %%
repo = json_resp['items'][0]
print(repo["name"])
print(repo["description"])
# Out:
# requests
# Python HTTP Requests for Humans™ ✨🍰✨

# %% [markdown]
# ## Concept of query strings - [II] Passing params in the form of a list of tuples

# %%
resp = requests.get("https://api.github.com/search/repositories", 
                    params = [('q','requests+language:r')])            # List of Tuples
json_resp = resp.json()

import json
print(json.dumps(json_resp, indent=4, sort_keys=True))
# Out:
# {
#     "incomplete_results": false,
#     "items": [
#         {
#             "archive_url": "https://api.github.com/repos/r-lib/async/{archive_format}{/ref}",
#             "archived": false,
#             "assignees_url": "https://api.github.com/repos/r-lib/async/assignees{/user}",
#             "blobs_url": "https://api.github.com/repos/r-lib/async/git/blobs{/sha}",
#             "branches_url": "https://api.github.com/repos/r-lib/async/branches{/branch}",
#             "clone_url": "https://github.com/r-lib/async.git",
#             "collaborators_url": "https://api.github.com/repos/r-lib/async/collaborators{/collaborator}",
#             "comments_url": "https://api.github.com/repos/r-lib/async/comments{/number}",
#             "commits_url": "https://api.github.com/repos/r-lib/async/commits{/sha}",
#             "compare_url": "https://api.github.com/repos/r-lib/async/compare/{base}...{head}",
#             "contents_url": "https://api.github.com/repos/r-lib/async/contents/{+path}",
#             "contributors_url": "https://api.github.com/repos/r-lib/async/contributors",
#             "created_at": "2017-08-11T12:38:17Z",
#             "default_branch": "master",
#             "deployments_url": "https://api.github.com/repos/r-lib/async/deployments",
#             "description": "Asynchronous HTTP requests in R -- UNDER CONSTRUCTION",
#             "downloads_url": "https://api.github.com/repos/r-lib/async/downloads",
#             "events_url": "https://api.github.com/repos/r-lib/async/events",
#             "fork": false,
#             "forks": 5,
#             "forks_count": 5,
#             "forks_url": "https://api.github.com/repos/r-lib/async/forks",
#             "full_name": "r-lib/async",
#             "git_commits_url": "https://api.github.com/repos/r-lib/async/git/commits{/sha}",
#             "git_refs_url": "https://api.github.com/repos/r-lib/async/git/refs{/sha}",
#             "git_tags_url": "https://api.github.com/repos/r-lib/async/git/tags{/sha}",
#             "git_url": "git://github.com/r-lib/async.git",
#             "has_downloads": true,
#             "has_issues": true,
#             "has_pages": false,
#             "has_projects": true,
#             "has_wiki": true,
#             "homepage": "",
#             "hooks_url": "https://api.github.com/repos/r-lib/async/hooks",
#             "html_url": "https://github.com/r-lib/async",
#             "id": 100029965,
#             "issue_comment_url": "https://api.github.com/repos/r-lib/async/issues/comments{/number}",
#             "issue_events_url": "https://api.github.com/repos/r-lib/async/issues/events{/number}",
#             "issues_url": "https://api.github.com/repos/r-lib/async/issues{/number}",
#             "keys_url": "https://api.github.com/repos/r-lib/async/keys{/key_id}",
#             "labels_url": "https://api.github.com/repos/r-lib/async/labels{/name}",
#             "language": "R",
#             "languages_url": "https://api.github.com/repos/r-lib/async/languages",
#             "license": {
#                 "key": "other",
#                 "name": "Other",
#                 "node_id": "MDc6TGljZW5zZTA=",
#                 "spdx_id": "NOASSERTION",
#                 "url": null
#             },
#             "merges_url": "https://api.github.com/repos/r-lib/async/merges",
#             "milestones_url": "https://api.github.com/repos/r-lib/async/milestones{/number}",
#             "mirror_url": null,
#             "name": "async",
#             "node_id": "MDEwOlJlcG9zaXRvcnkxMDAwMjk5NjU=",
#             "notifications_url": "https://api.github.com/repos/r-lib/async/notifications{?since,all,participating}",
#             "open_issues": 3,
#             "open_issues_count": 3,
#             "owner": {
#                 "avatar_url": "https://avatars0.githubusercontent.com/u/22618716?v=4",
#                 "events_url": "https://api.github.com/users/r-lib/events{/privacy}",
#                 "followers_url": "https://api.github.com/users/r-lib/followers",
#                 "following_url": "https://api.github.com/users/r-lib/following{/other_user}",
#                 "gists_url": "https://api.github.com/users/r-lib/gists{/gist_id}",
#                 "gravatar_id": "",
#                 "html_url": "https://github.com/r-lib",
#                 "id": 22618716,
#                 "login": "r-lib",
#                 "node_id": "MDEyOk9yZ2FuaXphdGlvbjIyNjE4NzE2",
#                 "organizations_url": "https://api.github.com/users/r-lib/orgs",
#                 "received_events_url": "https://api.github.com/users/r-lib/received_events",
#                 "repos_url": "https://api.github.com/users/r-lib/repos",
#                 "site_admin": false,
#                 "starred_url": "https://api.github.com/users/r-lib/starred{/owner}{/repo}",
#                 "subscriptions_url": "https://api.github.com/users/r-lib/subscriptions",
#                 "type": "Organization",
#                 "url": "https://api.github.com/users/r-lib"
#             },
#             "private": false,
#             "pulls_url": "https://api.github.com/repos/r-lib/async/pulls{/number}",
#             "pushed_at": "2018-12-05T13:39:57Z",
#             "releases_url": "https://api.github.com/repos/r-lib/async/releases{/id}",
#             "score": 36.513027,
#             "size": 579,
#             "ssh_url": "git@github.com:r-lib/async.git",
#             "stargazers_count": 63,
#             "stargazers_url": "https://api.github.com/repos/r-lib/async/stargazers",
#             "statuses_url": "https://api.github.com/repos/r-lib/async/statuses/{sha}",
#             "subscribers_url": "https://api.github.com/repos/r-lib/async/subscribers",
#             "subscription_url": "https://api.github.com/repos/r-lib/async/subscription",
#             "svn_url": "https://github.com/r-lib/async",
#             "tags_url": "https://api.github.com/repos/r-lib/async/tags",
#             "teams_url": "https://api.github.com/repos/r-lib/async/teams",
#             "trees_url": "https://api.github.com/repos/r-lib/async/git/trees{/sha}",
#             "updated_at": "2019-01-20T23:58:08Z",
#             "url": "https://api.github.com/repos/r-lib/async",
#             "watchers": 63,
#             "watchers_count": 63
#         },
#         {
#             "archive_url": "https://api.github.com/repos/eclee25/the-rat-hack/{archive_format}{/ref}",
#             "archived": false,
#             "assignees_url": "https://api.github.com/repos/eclee25/the-rat-hack/assignees{/user}",
#             "blobs_url": "https://api.github.com/repos/eclee25/the-rat-hack/git/blobs{/sha}",
#             "branches_url": "https://api.github.com/repos/eclee25/the-rat-hack/branches{/branch}",
#             "clone_url": "https://github.com/eclee25/the-rat-hack.git",
#             "collaborators_url": "https://api.github.com/repos/eclee25/the-rat-hack/collaborators{/collaborator}",
#             "comments_url": "https://api.github.com/repos/eclee25/the-rat-hack/comments{/number}",
#             "commits_url": "https://api.github.com/repos/eclee25/the-rat-hack/commits{/sha}",
#             "compare_url": "https://api.github.com/repos/eclee25/the-rat-hack/compare/{base}...{head}",
#             "contents_url": "https://api.github.com/repos/eclee25/the-rat-hack/contents/{+path}",
#             "contributors_url": "https://api.github.com/repos/eclee25/the-rat-hack/contributors",
#             "created_at": "2017-01-13T01:38:43Z",
#             "default_branch": "master",
#             "deployments_url": "https://api.github.com/repos/eclee25/the-rat-hack/deployments",
#             "description": "explore DC 311 rodent abatement requests",
#             "downloads_url": "https://api.github.com/repos/eclee25/the-rat-hack/downloads",
#             "events_url": "https://api.github.com/repos/eclee25/the-rat-hack/events",
#             "fork": false,
#             "forks": 14,
#             "forks_count": 14,
#             "forks_url": "https://api.github.com/repos/eclee25/the-rat-hack/forks",
#             "full_name": "eclee25/the-rat-hack",
#             "git_commits_url": "https://api.github.com/repos/eclee25/the-rat-hack/git/commits{/sha}",
#             "git_refs_url": "https://api.github.com/repos/eclee25/the-rat-hack/git/refs{/sha}",
#             "git_tags_url": "https://api.github.com/repos/eclee25/the-rat-hack/git/tags{/sha}",
#             "git_url": "git://github.com/eclee25/the-rat-hack.git",
#             "has_downloads": true,
#             "has_issues": true,
#             "has_pages": true,
#             "has_projects": true,
#             "has_wiki": true,
#             "homepage": null,
#             "hooks_url": "https://api.github.com/repos/eclee25/the-rat-hack/hooks",
#             "html_url": "https://github.com/eclee25/the-rat-hack",
#             "id": 78803897,
#             "issue_comment_url": "https://api.github.com/repos/eclee25/the-rat-hack/issues/comments{/number}",
#             "issue_events_url": "https://api.github.com/repos/eclee25/the-rat-hack/issues/events{/number}",
#             "issues_url": "https://api.github.com/repos/eclee25/the-rat-hack/issues{/number}",
#             "keys_url": "https://api.github.com/repos/eclee25/the-rat-hack/keys{/key_id}",
#             "labels_url": "https://api.github.com/repos/eclee25/the-rat-hack/labels{/name}",
#             "language": "R",
#             "languages_url": "https://api.github.com/repos/eclee25/the-rat-hack/languages",
#             "license": null,
#             "merges_url": "https://api.github.com/repos/eclee25/the-rat-hack/merges",
#             "milestones_url": "https://api.github.com/repos/eclee25/the-rat-hack/milestones{/number}",
#             "mirror_url": null,
#             "name": "the-rat-hack",
#             "node_id": "MDEwOlJlcG9zaXRvcnk3ODgwMzg5Nw==",
#             "notifications_url": "https://api.github.com/repos/eclee25/the-rat-hack/notifications{?since,all,participating}",
#             "open_issues": 1,
#             "open_issues_count": 1,
#             "owner": {
#                 "avatar_url": "https://avatars2.githubusercontent.com/u/5208766?v=4",
#                 "events_url": "https://api.github.com/users/eclee25/events{/privacy}",
#                 "followers_url": "https://api.github.com/users/eclee25/followers",
#                 "following_url": "https://api.github.com/users/eclee25/following{/other_user}",
#                 "gists_url": "https://api.github.com/users/eclee25/gists{/gist_id}",
#                 "gravatar_id": "",
#                 "html_url": "https://github.com/eclee25",
#                 "id": 5208766,
#                 "login": "eclee25",
#                 "node_id": "MDQ6VXNlcjUyMDg3NjY=",
#                 "organizations_url": "https://api.github.com/users/eclee25/orgs",
#                 "received_events_url": "https://api.github.com/users/eclee25/received_events",
#                 "repos_url": "https://api.github.com/users/eclee25/repos",
#                 "site_admin": false,
#                 "starred_url": "https://api.github.com/users/eclee25/starred{/owner}{/repo}",
#                 "subscriptions_url": "https://api.github.com/users/eclee25/subscriptions",
#                 "type": "User",
#                 "url": "https://api.github.com/users/eclee25"
#             },
#             "private": false,
#             "pulls_url": "https://api.github.com/repos/eclee25/the-rat-hack/pulls{/number}",
#             "pushed_at": "2018-01-14T22:11:11Z",
#             "releases_url": "https://api.github.com/repos/eclee25/the-rat-hack/releases{/id}",
#             "score": 36.064396,
#             "size": 5173,
#             "ssh_url": "git@github.com:eclee25/the-rat-hack.git",
#             "stargazers_count": 5,
#             "stargazers_url": "https://api.github.com/repos/eclee25/the-rat-hack/stargazers",
#             "statuses_url": "https://api.github.com/repos/eclee25/the-rat-hack/statuses/{sha}",
#             "subscribers_url": "https://api.github.com/repos/eclee25/the-rat-hack/subscribers",
#             "subscription_url": "https://api.github.com/repos/eclee25/the-rat-hack/subscription",
#             "svn_url": "https://github.com/eclee25/the-rat-hack",
#             "tags_url": "https://api.github.com/repos/eclee25/the-rat-hack/tags",
#             "teams_url": "https://api.github.com/repos/eclee25/the-rat-hack/teams",
#             "trees_url": "https://api.github.com/repos/eclee25/the-rat-hack/git/trees{/sha}",
#             "updated_at": "2018-04-12T01:24:59Z",
#             "url": "https://api.github.com/repos/eclee25/the-rat-hack",
#             "watchers": 5,
#             "watchers_count": 5
#         },
#         {
#             "archive_url": "https://api.github.com/repos/cloudyr/MTurkR/{archive_format}{/ref}",
#             "archived": false,
#             "assignees_url": "https://api.github.com/repos/cloudyr/MTurkR/assignees{/user}",
#             "blobs_url": "https://api.github.com/repos/cloudyr/MTurkR/git/blobs{/sha}",
#             "branches_url": "https://api.github.com/repos/cloudyr/MTurkR/branches{/branch}",
#             "clone_url": "https://github.com/cloudyr/MTurkR.git",
#             "collaborators_url": "https://api.github.com/repos/cloudyr/MTurkR/collaborators{/collaborator}",
#             "comments_url": "https://api.github.com/repos/cloudyr/MTurkR/comments{/number}",
#             "commits_url": "https://api.github.com/repos/cloudyr/MTurkR/commits{/sha}",
#             "compare_url": "https://api.github.com/repos/cloudyr/MTurkR/compare/{base}...{head}",
#             "contents_url": "https://api.github.com/repos/cloudyr/MTurkR/contents/{+path}",
#             "contributors_url": "https://api.github.com/repos/cloudyr/MTurkR/contributors",
#             "created_at": "2013-06-09T23:50:08Z",
#             "default_branch": "master",
#             "deployments_url": "https://api.github.com/repos/cloudyr/MTurkR/deployments",
#             "description": "R Client for the MTurk Requester API",
#             "downloads_url": "https://api.github.com/repos/cloudyr/MTurkR/downloads",
#             "events_url": "https://api.github.com/repos/cloudyr/MTurkR/events",
#             "fork": false,
#             "forks": 15,
#             "forks_count": 15,
#             "forks_url": "https://api.github.com/repos/cloudyr/MTurkR/forks",
#             "full_name": "cloudyr/MTurkR",
#             "git_commits_url": "https://api.github.com/repos/cloudyr/MTurkR/git/commits{/sha}",
#             "git_refs_url": "https://api.github.com/repos/cloudyr/MTurkR/git/refs{/sha}",
#             "git_tags_url": "https://api.github.com/repos/cloudyr/MTurkR/git/tags{/sha}",
#             "git_url": "git://github.com/cloudyr/MTurkR.git",
#             "has_downloads": true,
#             "has_issues": true,
#             "has_pages": true,
#             "has_projects": true,
#             "has_wiki": true,
#             "homepage": "https://cloud.r-project.org/package=MTurkR",
#             "hooks_url": "https://api.github.com/repos/cloudyr/MTurkR/hooks",
#             "html_url": "https://github.com/cloudyr/MTurkR",
#             "id": 10590816,
#             "issue_comment_url": "https://api.github.com/repos/cloudyr/MTurkR/issues/comments{/number}",
#             "issue_events_url": "https://api.github.com/repos/cloudyr/MTurkR/issues/events{/number}",
#             "issues_url": "https://api.github.com/repos/cloudyr/MTurkR/issues{/number}",
#             "keys_url": "https://api.github.com/repos/cloudyr/MTurkR/keys{/key_id}",
#             "labels_url": "https://api.github.com/repos/cloudyr/MTurkR/labels{/name}",
#             "language": "R",
#             "languages_url": "https://api.github.com/repos/cloudyr/MTurkR/languages",
#             "license": null,
#             "merges_url": "https://api.github.com/repos/cloudyr/MTurkR/merges",
#             "milestones_url": "https://api.github.com/repos/cloudyr/MTurkR/milestones{/number}",
#             "mirror_url": null,
#             "name": "MTurkR",
#             "node_id": "MDEwOlJlcG9zaXRvcnkxMDU5MDgxNg==",
#             "notifications_url": "https://api.github.com/repos/cloudyr/MTurkR/notifications{?since,all,participating}",
#             "open_issues": 6,
#             "open_issues_count": 6,
#             "owner": {
#                 "avatar_url": "https://avatars0.githubusercontent.com/u/10290205?v=4",
#                 "events_url": "https://api.github.com/users/cloudyr/events{/privacy}",
#                 "followers_url": "https://api.github.com/users/cloudyr/followers",
#                 "following_url": "https://api.github.com/users/cloudyr/following{/other_user}",
#                 "gists_url": "https://api.github.com/users/cloudyr/gists{/gist_id}",
#                 "gravatar_id": "",
#                 "html_url": "https://github.com/cloudyr",
#                 "id": 10290205,
#                 "login": "cloudyr",
#                 "node_id": "MDEyOk9yZ2FuaXphdGlvbjEwMjkwMjA1",
#                 "organizations_url": "https://api.github.com/users/cloudyr/orgs",
#                 "received_events_url": "https://api.github.com/users/cloudyr/received_events",
#                 "repos_url": "https://api.github.com/users/cloudyr/repos",
#                 "site_admin": false,
#                 "starred_url": "https://api.github.com/users/cloudyr/starred{/owner}{/repo}",
#                 "subscriptions_url": "https://api.github.com/users/cloudyr/subscriptions",
#                 "type": "Organization",
#                 "url": "https://api.github.com/users/cloudyr"
#             },
#             "private": false,
#             "pulls_url": "https://api.github.com/repos/cloudyr/MTurkR/pulls{/number}",
#             "pushed_at": "2018-04-02T21:45:55Z",
#             "releases_url": "https://api.github.com/repos/cloudyr/MTurkR/releases{/id}",
#             "score": 35.64404,
#             "size": 2215,
#             "ssh_url": "git@github.com:cloudyr/MTurkR.git",
#             "stargazers_count": 84,
#             "stargazers_url": "https://api.github.com/repos/cloudyr/MTurkR/stargazers",
#             "statuses_url": "https://api.github.com/repos/cloudyr/MTurkR/statuses/{sha}",
#             "subscribers_url": "https://api.github.com/repos/cloudyr/MTurkR/subscribers",
#             "subscription_url": "https://api.github.com/repos/cloudyr/MTurkR/subscription",
#             "svn_url": "https://github.com/cloudyr/MTurkR",
#             "tags_url": "https://api.github.com/repos/cloudyr/MTurkR/tags",
#             "teams_url": "https://api.github.com/repos/cloudyr/MTurkR/teams",
#             "trees_url": "https://api.github.com/repos/cloudyr/MTurkR/git/trees{/sha}",
#             "updated_at": "2019-02-17T21:38:47Z",
#             "url": "https://api.github.com/repos/cloudyr/MTurkR",
#             "watchers": 84,
#             "watchers_count": 84
#         },
#         {
#             "archive_url": "https://api.github.com/repos/cloudyr/aws.signature/{archive_format}{/ref}",
#             "archived": false,
#             "assignees_url": "https://api.github.com/repos/cloudyr/aws.signature/assignees{/user}",
#             "blobs_url": "https://api.github.com/repos/cloudyr/aws.signature/git/blobs{/sha}",
#             "branches_url": "https://api.github.com/repos/cloudyr/aws.signature/branches{/branch}",
#             "clone_url": "https://github.com/cloudyr/aws.signature.git",
#             "collaborators_url": "https://api.github.com/repos/cloudyr/aws.signature/collaborators{/collaborator}",
#             "comments_url": "https://api.github.com/repos/cloudyr/aws.signature/comments{/number}",
#             "commits_url": "https://api.github.com/repos/cloudyr/aws.signature/commits{/sha}",
#             "compare_url": "https://api.github.com/repos/cloudyr/aws.signature/compare/{base}...{head}",
#             "contents_url": "https://api.github.com/repos/cloudyr/aws.signature/contents/{+path}",
#             "contributors_url": "https://api.github.com/repos/cloudyr/aws.signature/contributors",
#             "created_at": "2014-12-10T19:07:22Z",
#             "default_branch": "master",
#             "deployments_url": "https://api.github.com/repos/cloudyr/aws.signature/deployments",
#             "description": "Amazon Web Services Request Signatures",
#             "downloads_url": "https://api.github.com/repos/cloudyr/aws.signature/downloads",
#             "events_url": "https://api.github.com/repos/cloudyr/aws.signature/events",
#             "fork": false,
#             "forks": 19,
#             "forks_count": 19,
#             "forks_url": "https://api.github.com/repos/cloudyr/aws.signature/forks",
#             "full_name": "cloudyr/aws.signature",
#             "git_commits_url": "https://api.github.com/repos/cloudyr/aws.signature/git/commits{/sha}",
#             "git_refs_url": "https://api.github.com/repos/cloudyr/aws.signature/git/refs{/sha}",
#             "git_tags_url": "https://api.github.com/repos/cloudyr/aws.signature/git/tags{/sha}",
#             "git_url": "git://github.com/cloudyr/aws.signature.git",
#             "has_downloads": true,
#             "has_issues": true,
#             "has_pages": false,
#             "has_projects": true,
#             "has_wiki": true,
#             "homepage": "https://cloud.r-project.org/package=aws.signature",
#             "hooks_url": "https://api.github.com/repos/cloudyr/aws.signature/hooks",
#             "html_url": "https://github.com/cloudyr/aws.signature",
#             "id": 27834983,
#             "issue_comment_url": "https://api.github.com/repos/cloudyr/aws.signature/issues/comments{/number}",
#             "issue_events_url": "https://api.github.com/repos/cloudyr/aws.signature/issues/events{/number}",
#             "issues_url": "https://api.github.com/repos/cloudyr/aws.signature/issues{/number}",
#             "keys_url": "https://api.github.com/repos/cloudyr/aws.signature/keys{/key_id}",
#             "labels_url": "https://api.github.com/repos/cloudyr/aws.signature/labels{/name}",
#             "language": "R",
#             "languages_url": "https://api.github.com/repos/cloudyr/aws.signature/languages",
#             "license": null,
#             "merges_url": "https://api.github.com/repos/cloudyr/aws.signature/merges",
#             "milestones_url": "https://api.github.com/repos/cloudyr/aws.signature/milestones{/number}",
#             "mirror_url": null,
#             "name": "aws.signature",
#             "node_id": "MDEwOlJlcG9zaXRvcnkyNzgzNDk4Mw==",
#             "notifications_url": "https://api.github.com/repos/cloudyr/aws.signature/notifications{?since,all,participating}",
#             "open_issues": 12,
#             "open_issues_count": 12,
#             "owner": {
#                 "avatar_url": "https://avatars0.githubusercontent.com/u/10290205?v=4",
#                 "events_url": "https://api.github.com/users/cloudyr/events{/privacy}",
#                 "followers_url": "https://api.github.com/users/cloudyr/followers",
#                 "following_url": "https://api.github.com/users/cloudyr/following{/other_user}",
#                 "gists_url": "https://api.github.com/users/cloudyr/gists{/gist_id}",
#                 "gravatar_id": "",
#                 "html_url": "https://github.com/cloudyr",
#                 "id": 10290205,
#                 "login": "cloudyr",
#                 "node_id": "MDEyOk9yZ2FuaXphdGlvbjEwMjkwMjA1",
#                 "organizations_url": "https://api.github.com/users/cloudyr/orgs",
#                 "received_events_url": "https://api.github.com/users/cloudyr/received_events",
#                 "repos_url": "https://api.github.com/users/cloudyr/repos",
#                 "site_admin": false,
#                 "starred_url": "https://api.github.com/users/cloudyr/starred{/owner}{/repo}",
#                 "subscriptions_url": "https://api.github.com/users/cloudyr/subscriptions",
#                 "type": "Organization",
#                 "url": "https://api.github.com/users/cloudyr"
#             },
#             "private": false,
#             "pulls_url": "https://api.github.com/repos/cloudyr/aws.signature/pulls{/number}",
#             "pushed_at": "2018-12-04T23:41:08Z",
#             "releases_url": "https://api.github.com/repos/cloudyr/aws.signature/releases{/id}",
#             "score": 34.845142,
#             "size": 137,
#             "ssh_url": "git@github.com:cloudyr/aws.signature.git",
#             "stargazers_count": 14,
#             "stargazers_url": "https://api.github.com/repos/cloudyr/aws.signature/stargazers",
#             "statuses_url": "https://api.github.com/repos/cloudyr/aws.signature/statuses/{sha}",
#             "subscribers_url": "https://api.github.com/repos/cloudyr/aws.signature/subscribers",
#             "subscription_url": "https://api.github.com/repos/cloudyr/aws.signature/subscription",
#             "svn_url": "https://github.com/cloudyr/aws.signature",
#             "tags_url": "https://api.github.com/repos/cloudyr/aws.signature/tags",
#             "teams_url": "https://api.github.com/repos/cloudyr/aws.signature/teams",
#             "trees_url": "https://api.github.com/repos/cloudyr/aws.signature/git/trees{/sha}",
#             "updated_at": "2019-01-31T03:55:22Z",
#             "url": "https://api.github.com/repos/cloudyr/aws.signature",
#             "watchers": 14,
#             "watchers_count": 14
#         },
#         {
#             "archive_url": "https://api.github.com/repos/Bioconductor/BiocStyle/{archive_format}{/ref}",
#             "archived": false,
#             "assignees_url": "https://api.github.com/repos/Bioconductor/BiocStyle/assignees{/user}",
#             "blobs_url": "https://api.github.com/repos/Bioconductor/BiocStyle/git/blobs{/sha}",
#             "branches_url": "https://api.github.com/repos/Bioconductor/BiocStyle/branches{/branch}",
#             "clone_url": "https://github.com/Bioconductor/BiocStyle.git",
#             "collaborators_url": "https://api.github.com/repos/Bioconductor/BiocStyle/collaborators{/collaborator}",
#             "comments_url": "https://api.github.com/repos/Bioconductor/BiocStyle/comments{/number}",
#             "commits_url": "https://api.github.com/repos/Bioconductor/BiocStyle/commits{/sha}",
#             "compare_url": "https://api.github.com/repos/Bioconductor/BiocStyle/compare/{base}...{head}",
#             "contents_url": "https://api.github.com/repos/Bioconductor/BiocStyle/contents/{+path}",
#             "contributors_url": "https://api.github.com/repos/Bioconductor/BiocStyle/contributors",
#             "created_at": "2015-07-30T18:34:17Z",
#             "default_branch": "master",
#             "deployments_url": "https://api.github.com/repos/Bioconductor/BiocStyle/deployments",
#             "description": "Issues and pull requests for BiocStyle should go here.",
#             "downloads_url": "https://api.github.com/repos/Bioconductor/BiocStyle/downloads",
#             "events_url": "https://api.github.com/repos/Bioconductor/BiocStyle/events",
#             "fork": false,
#             "forks": 13,
#             "forks_count": 13,
#             "forks_url": "https://api.github.com/repos/Bioconductor/BiocStyle/forks",
#             "full_name": "Bioconductor/BiocStyle",
#             "git_commits_url": "https://api.github.com/repos/Bioconductor/BiocStyle/git/commits{/sha}",
#             "git_refs_url": "https://api.github.com/repos/Bioconductor/BiocStyle/git/refs{/sha}",
#             "git_tags_url": "https://api.github.com/repos/Bioconductor/BiocStyle/git/tags{/sha}",
#             "git_url": "git://github.com/Bioconductor/BiocStyle.git",
#             "has_downloads": false,
#             "has_issues": true,
#             "has_pages": false,
#             "has_projects": true,
#             "has_wiki": false,
#             "homepage": "",
#             "hooks_url": "https://api.github.com/repos/Bioconductor/BiocStyle/hooks",
#             "html_url": "https://github.com/Bioconductor/BiocStyle",
#             "id": 39966270,
#             "issue_comment_url": "https://api.github.com/repos/Bioconductor/BiocStyle/issues/comments{/number}",
#             "issue_events_url": "https://api.github.com/repos/Bioconductor/BiocStyle/issues/events{/number}",
#             "issues_url": "https://api.github.com/repos/Bioconductor/BiocStyle/issues{/number}",
#             "keys_url": "https://api.github.com/repos/Bioconductor/BiocStyle/keys{/key_id}",
#             "labels_url": "https://api.github.com/repos/Bioconductor/BiocStyle/labels{/name}",
#             "language": "R",
#             "languages_url": "https://api.github.com/repos/Bioconductor/BiocStyle/languages",
#             "license": null,
#             "merges_url": "https://api.github.com/repos/Bioconductor/BiocStyle/merges",
#             "milestones_url": "https://api.github.com/repos/Bioconductor/BiocStyle/milestones{/number}",
#             "mirror_url": null,
#             "name": "BiocStyle",
#             "node_id": "MDEwOlJlcG9zaXRvcnkzOTk2NjI3MA==",
#             "notifications_url": "https://api.github.com/repos/Bioconductor/BiocStyle/notifications{?since,all,participating}",
#             "open_issues": 16,
#             "open_issues_count": 16,
#             "owner": {
#                 "avatar_url": "https://avatars3.githubusercontent.com/u/2286807?v=4",
#                 "events_url": "https://api.github.com/users/Bioconductor/events{/privacy}",
#                 "followers_url": "https://api.github.com/users/Bioconductor/followers",
#                 "following_url": "https://api.github.com/users/Bioconductor/following{/other_user}",
#                 "gists_url": "https://api.github.com/users/Bioconductor/gists{/gist_id}",
#                 "gravatar_id": "",
#                 "html_url": "https://github.com/Bioconductor",
#                 "id": 2286807,
#                 "login": "Bioconductor",
#                 "node_id": "MDEyOk9yZ2FuaXphdGlvbjIyODY4MDc=",
#                 "organizations_url": "https://api.github.com/users/Bioconductor/orgs",
#                 "received_events_url": "https://api.github.com/users/Bioconductor/received_events",
#                 "repos_url": "https://api.github.com/users/Bioconductor/repos",
#                 "site_admin": false,
#                 "starred_url": "https://api.github.com/users/Bioconductor/starred{/owner}{/repo}",
#                 "subscriptions_url": "https://api.github.com/users/Bioconductor/subscriptions",
#                 "type": "Organization",
#                 "url": "https://api.github.com/users/Bioconductor"
#             },
#             "private": false,
#             "pulls_url": "https://api.github.com/repos/Bioconductor/BiocStyle/pulls{/number}",
#             "pushed_at": "2018-10-30T17:57:21Z",
#             "releases_url": "https://api.github.com/repos/Bioconductor/BiocStyle/releases{/id}",
#             "score": 34.00665,
#             "size": 434,
#             "ssh_url": "git@github.com:Bioconductor/BiocStyle.git",
#             "stargazers_count": 8,
#             "stargazers_url": "https://api.github.com/repos/Bioconductor/BiocStyle/stargazers",
#             "statuses_url": "https://api.github.com/repos/Bioconductor/BiocStyle/statuses/{sha}",
#             "subscribers_url": "https://api.github.com/repos/Bioconductor/BiocStyle/subscribers",
#             "subscription_url": "https://api.github.com/repos/Bioconductor/BiocStyle/subscription",
#             "svn_url": "https://github.com/Bioconductor/BiocStyle",
#             "tags_url": "https://api.github.com/repos/Bioconductor/BiocStyle/tags",
#             "teams_url": "https://api.github.com/repos/Bioconductor/BiocStyle/teams",
#             "trees_url": "https://api.github.com/repos/Bioconductor/BiocStyle/git/trees{/sha}",
#             "updated_at": "2018-10-30T17:57:20Z",
#             "url": "https://api.github.com/repos/Bioconductor/BiocStyle",
#             "watchers": 8,
#             "watchers_count": 8
#         },
#         {
#             "archive_url": "https://api.github.com/repos/joyofdata/RTwitterAPI/{archive_format}{/ref}",
#             "archived": false,
#             "assignees_url": "https://api.github.com/repos/joyofdata/RTwitterAPI/assignees{/user}",
#             "blobs_url": "https://api.github.com/repos/joyofdata/RTwitterAPI/git/blobs{/sha}",
#             "branches_url": "https://api.github.com/repos/joyofdata/RTwitterAPI/branches{/branch}",
#             "clone_url": "https://github.com/joyofdata/RTwitterAPI.git",
#             "collaborators_url": "https://api.github.com/repos/joyofdata/RTwitterAPI/collaborators{/collaborator}",
#             "comments_url": "https://api.github.com/repos/joyofdata/RTwitterAPI/comments{/number}",
#             "commits_url": "https://api.github.com/repos/joyofdata/RTwitterAPI/commits{/sha}",
#             "compare_url": "https://api.github.com/repos/joyofdata/RTwitterAPI/compare/{base}...{head}",
#             "contents_url": "https://api.github.com/repos/joyofdata/RTwitterAPI/contents/{+path}",
#             "contributors_url": "https://api.github.com/repos/joyofdata/RTwitterAPI/contributors",
#             "created_at": "2014-06-10T13:44:24Z",
#             "default_branch": "master",
#             "deployments_url": "https://api.github.com/repos/joyofdata/RTwitterAPI/deployments",
#             "description": "Making requests to Twitter's REST API v1.1",
#             "downloads_url": "https://api.github.com/repos/joyofdata/RTwitterAPI/downloads",
#             "events_url": "https://api.github.com/repos/joyofdata/RTwitterAPI/events",
#             "fork": false,
#             "forks": 11,
#             "forks_count": 11,
#             "forks_url": "https://api.github.com/repos/joyofdata/RTwitterAPI/forks",
#             "full_name": "joyofdata/RTwitterAPI",
#             "git_commits_url": "https://api.github.com/repos/joyofdata/RTwitterAPI/git/commits{/sha}",
#             "git_refs_url": "https://api.github.com/repos/joyofdata/RTwitterAPI/git/refs{/sha}",
#             "git_tags_url": "https://api.github.com/repos/joyofdata/RTwitterAPI/git/tags{/sha}",
#             "git_url": "git://github.com/joyofdata/RTwitterAPI.git",
#             "has_downloads": true,
#             "has_issues": true,
#             "has_pages": false,
#             "has_projects": true,
#             "has_wiki": true,
#             "homepage": null,
#             "hooks_url": "https://api.github.com/repos/joyofdata/RTwitterAPI/hooks",
#             "html_url": "https://github.com/joyofdata/RTwitterAPI",
#             "id": 20686744,
#             "issue_comment_url": "https://api.github.com/repos/joyofdata/RTwitterAPI/issues/comments{/number}",
#             "issue_events_url": "https://api.github.com/repos/joyofdata/RTwitterAPI/issues/events{/number}",
#             "issues_url": "https://api.github.com/repos/joyofdata/RTwitterAPI/issues{/number}",
#             "keys_url": "https://api.github.com/repos/joyofdata/RTwitterAPI/keys{/key_id}",
#             "labels_url": "https://api.github.com/repos/joyofdata/RTwitterAPI/labels{/name}",
#             "language": "R",
#             "languages_url": "https://api.github.com/repos/joyofdata/RTwitterAPI/languages",
#             "license": {
#                 "key": "mit",
#                 "name": "MIT License",
#                 "node_id": "MDc6TGljZW5zZTEz",
#                 "spdx_id": "MIT",
#                 "url": "https://api.github.com/licenses/mit"
#             },
#             "merges_url": "https://api.github.com/repos/joyofdata/RTwitterAPI/merges",
#             "milestones_url": "https://api.github.com/repos/joyofdata/RTwitterAPI/milestones{/number}",
#             "mirror_url": null,
#             "name": "RTwitterAPI",
#             "node_id": "MDEwOlJlcG9zaXRvcnkyMDY4Njc0NA==",
#             "notifications_url": "https://api.github.com/repos/joyofdata/RTwitterAPI/notifications{?since,all,participating}",
#             "open_issues": 0,
#             "open_issues_count": 0,
#             "owner": {
#                 "avatar_url": "https://avatars1.githubusercontent.com/u/3748975?v=4",
#                 "events_url": "https://api.github.com/users/joyofdata/events{/privacy}",
#                 "followers_url": "https://api.github.com/users/joyofdata/followers",
#                 "following_url": "https://api.github.com/users/joyofdata/following{/other_user}",
#                 "gists_url": "https://api.github.com/users/joyofdata/gists{/gist_id}",
#                 "gravatar_id": "",
#                 "html_url": "https://github.com/joyofdata",
#                 "id": 3748975,
#                 "login": "joyofdata",
#                 "node_id": "MDQ6VXNlcjM3NDg5NzU=",
#                 "organizations_url": "https://api.github.com/users/joyofdata/orgs",
#                 "received_events_url": "https://api.github.com/users/joyofdata/received_events",
#                 "repos_url": "https://api.github.com/users/joyofdata/repos",
#                 "site_admin": false,
#                 "starred_url": "https://api.github.com/users/joyofdata/starred{/owner}{/repo}",
#                 "subscriptions_url": "https://api.github.com/users/joyofdata/subscriptions",
#                 "type": "User",
#                 "url": "https://api.github.com/users/joyofdata"
#             },
#             "private": false,
#             "pulls_url": "https://api.github.com/repos/joyofdata/RTwitterAPI/pulls{/number}",
#             "pushed_at": "2014-09-22T22:21:26Z",
#             "releases_url": "https://api.github.com/repos/joyofdata/RTwitterAPI/releases{/id}",
#             "score": 33.47278,
#             "size": 281,
#             "ssh_url": "git@github.com:joyofdata/RTwitterAPI.git",
#             "stargazers_count": 10,
#             "stargazers_url": "https://api.github.com/repos/joyofdata/RTwitterAPI/stargazers",
#             "statuses_url": "https://api.github.com/repos/joyofdata/RTwitterAPI/statuses/{sha}",
#             "subscribers_url": "https://api.github.com/repos/joyofdata/RTwitterAPI/subscribers",
#             "subscription_url": "https://api.github.com/repos/joyofdata/RTwitterAPI/subscription",
#             "svn_url": "https://github.com/joyofdata/RTwitterAPI",
#             "tags_url": "https://api.github.com/repos/joyofdata/RTwitterAPI/tags",
#             "teams_url": "https://api.github.com/repos/joyofdata/RTwitterAPI/teams",
#             "trees_url": "https://api.github.com/repos/joyofdata/RTwitterAPI/git/trees{/sha}",
#             "updated_at": "2018-07-02T08:52:44Z",
#             "url": "https://api.github.com/repos/joyofdata/RTwitterAPI",
#             "watchers": 10,
#             "watchers_count": 10
#         },
#         {
#             "archive_url": "https://api.github.com/repos/thomasp85/routr/{archive_format}{/ref}",
#             "archived": false,
#             "assignees_url": "https://api.github.com/repos/thomasp85/routr/assignees{/user}",
#             "blobs_url": "https://api.github.com/repos/thomasp85/routr/git/blobs{/sha}",
#             "branches_url": "https://api.github.com/repos/thomasp85/routr/branches{/branch}",
#             "clone_url": "https://github.com/thomasp85/routr.git",
#             "collaborators_url": "https://api.github.com/repos/thomasp85/routr/collaborators{/collaborator}",
#             "comments_url": "https://api.github.com/repos/thomasp85/routr/comments{/number}",
#             "commits_url": "https://api.github.com/repos/thomasp85/routr/commits{/sha}",
#             "compare_url": "https://api.github.com/repos/thomasp85/routr/compare/{base}...{head}",
#             "contents_url": "https://api.github.com/repos/thomasp85/routr/contents/{+path}",
#             "contributors_url": "https://api.github.com/repos/thomasp85/routr/contributors",
#             "created_at": "2016-06-09T11:35:35Z",
#             "default_branch": "master",
#             "deployments_url": "https://api.github.com/repos/thomasp85/routr/deployments",
#             "description": "Routing of Web Requests in R",
#             "downloads_url": "https://api.github.com/repos/thomasp85/routr/downloads",
#             "events_url": "https://api.github.com/repos/thomasp85/routr/events",
#             "fork": false,
#             "forks": 4,
#             "forks_count": 4,
#             "forks_url": "https://api.github.com/repos/thomasp85/routr/forks",
#             "full_name": "thomasp85/routr",
#             "git_commits_url": "https://api.github.com/repos/thomasp85/routr/git/commits{/sha}",
#             "git_refs_url": "https://api.github.com/repos/thomasp85/routr/git/refs{/sha}",
#             "git_tags_url": "https://api.github.com/repos/thomasp85/routr/git/tags{/sha}",
#             "git_url": "git://github.com/thomasp85/routr.git",
#             "has_downloads": true,
#             "has_issues": true,
#             "has_pages": false,
#             "has_projects": true,
#             "has_wiki": true,
#             "homepage": null,
#             "hooks_url": "https://api.github.com/repos/thomasp85/routr/hooks",
#             "html_url": "https://github.com/thomasp85/routr",
#             "id": 60770171,
#             "issue_comment_url": "https://api.github.com/repos/thomasp85/routr/issues/comments{/number}",
#             "issue_events_url": "https://api.github.com/repos/thomasp85/routr/issues/events{/number}",
#             "issues_url": "https://api.github.com/repos/thomasp85/routr/issues{/number}",
#             "keys_url": "https://api.github.com/repos/thomasp85/routr/keys{/key_id}",
#             "labels_url": "https://api.github.com/repos/thomasp85/routr/labels{/name}",
#             "language": "R",
#             "languages_url": "https://api.github.com/repos/thomasp85/routr/languages",
#             "license": {
#                 "key": "other",
#                 "name": "Other",
#                 "node_id": "MDc6TGljZW5zZTA=",
#                 "spdx_id": "NOASSERTION",
#                 "url": null
#             },
#             "merges_url": "https://api.github.com/repos/thomasp85/routr/merges",
#             "milestones_url": "https://api.github.com/repos/thomasp85/routr/milestones{/number}",
#             "mirror_url": null,
#             "name": "routr",
#             "node_id": "MDEwOlJlcG9zaXRvcnk2MDc3MDE3MQ==",
#             "notifications_url": "https://api.github.com/repos/thomasp85/routr/notifications{?since,all,participating}",
#             "open_issues": 4,
#             "open_issues_count": 4,
#             "owner": {
#                 "avatar_url": "https://avatars3.githubusercontent.com/u/1775316?v=4",
#                 "events_url": "https://api.github.com/users/thomasp85/events{/privacy}",
#                 "followers_url": "https://api.github.com/users/thomasp85/followers",
#                 "following_url": "https://api.github.com/users/thomasp85/following{/other_user}",
#                 "gists_url": "https://api.github.com/users/thomasp85/gists{/gist_id}",
#                 "gravatar_id": "",
#                 "html_url": "https://github.com/thomasp85",
#                 "id": 1775316,
#                 "login": "thomasp85",
#                 "node_id": "MDQ6VXNlcjE3NzUzMTY=",
#                 "organizations_url": "https://api.github.com/users/thomasp85/orgs",
#                 "received_events_url": "https://api.github.com/users/thomasp85/received_events",
#                 "repos_url": "https://api.github.com/users/thomasp85/repos",
#                 "site_admin": false,
#                 "starred_url": "https://api.github.com/users/thomasp85/starred{/owner}{/repo}",
#                 "subscriptions_url": "https://api.github.com/users/thomasp85/subscriptions",
#                 "type": "User",
#                 "url": "https://api.github.com/users/thomasp85"
#             },
#             "private": false,
#             "pulls_url": "https://api.github.com/repos/thomasp85/routr/pulls{/number}",
#             "pushed_at": "2018-06-19T16:42:32Z",
#             "releases_url": "https://api.github.com/repos/thomasp85/routr/releases{/id}",
#             "score": 33.27217,
#             "size": 98,
#             "ssh_url": "git@github.com:thomasp85/routr.git",
#             "stargazers_count": 42,
#             "stargazers_url": "https://api.github.com/repos/thomasp85/routr/stargazers",
#             "statuses_url": "https://api.github.com/repos/thomasp85/routr/statuses/{sha}",
#             "subscribers_url": "https://api.github.com/repos/thomasp85/routr/subscribers",
#             "subscription_url": "https://api.github.com/repos/thomasp85/routr/subscription",
#             "svn_url": "https://github.com/thomasp85/routr",
#             "tags_url": "https://api.github.com/repos/thomasp85/routr/tags",
#             "teams_url": "https://api.github.com/repos/thomasp85/routr/teams",
#             "trees_url": "https://api.github.com/repos/thomasp85/routr/git/trees{/sha}",
#             "updated_at": "2019-02-04T23:09:18Z",
#             "url": "https://api.github.com/repos/thomasp85/routr",
#             "watchers": 42,
#             "watchers_count": 42
#         },
#         {
#             "archive_url": "https://api.github.com/repos/dlstrong/swc-forklesson/{archive_format}{/ref}",
#             "archived": false,
#             "assignees_url": "https://api.github.com/repos/dlstrong/swc-forklesson/assignees{/user}",
#             "blobs_url": "https://api.github.com/repos/dlstrong/swc-forklesson/git/blobs{/sha}",
#             "branches_url": "https://api.github.com/repos/dlstrong/swc-forklesson/branches{/branch}",
#             "clone_url": "https://github.com/dlstrong/swc-forklesson.git",
#             "collaborators_url": "https://api.github.com/repos/dlstrong/swc-forklesson/collaborators{/collaborator}",
#             "comments_url": "https://api.github.com/repos/dlstrong/swc-forklesson/comments{/number}",
#             "commits_url": "https://api.github.com/repos/dlstrong/swc-forklesson/commits{/sha}",
#             "compare_url": "https://api.github.com/repos/dlstrong/swc-forklesson/compare/{base}...{head}",
#             "contents_url": "https://api.github.com/repos/dlstrong/swc-forklesson/contents/{+path}",
#             "contributors_url": "https://api.github.com/repos/dlstrong/swc-forklesson/contributors",
#             "created_at": "2017-12-14T23:03:19Z",
#             "default_branch": "master",
#             "deployments_url": "https://api.github.com/repos/dlstrong/swc-forklesson/deployments",
#             "description": "Repository for Software Carpentry classes to fork and submit pull requests to",
#             "downloads_url": "https://api.github.com/repos/dlstrong/swc-forklesson/downloads",
#             "events_url": "https://api.github.com/repos/dlstrong/swc-forklesson/events",
#             "fork": false,
#             "forks": 47,
#             "forks_count": 47,
#             "forks_url": "https://api.github.com/repos/dlstrong/swc-forklesson/forks",
#             "full_name": "dlstrong/swc-forklesson",
#             "git_commits_url": "https://api.github.com/repos/dlstrong/swc-forklesson/git/commits{/sha}",
#             "git_refs_url": "https://api.github.com/repos/dlstrong/swc-forklesson/git/refs{/sha}",
#             "git_tags_url": "https://api.github.com/repos/dlstrong/swc-forklesson/git/tags{/sha}",
#             "git_url": "git://github.com/dlstrong/swc-forklesson.git",
#             "has_downloads": true,
#             "has_issues": true,
#             "has_pages": false,
#             "has_projects": true,
#             "has_wiki": true,
#             "homepage": "",
#             "hooks_url": "https://api.github.com/repos/dlstrong/swc-forklesson/hooks",
#             "html_url": "https://github.com/dlstrong/swc-forklesson",
#             "id": 114304550,
#             "issue_comment_url": "https://api.github.com/repos/dlstrong/swc-forklesson/issues/comments{/number}",
#             "issue_events_url": "https://api.github.com/repos/dlstrong/swc-forklesson/issues/events{/number}",
#             "issues_url": "https://api.github.com/repos/dlstrong/swc-forklesson/issues{/number}",
#             "keys_url": "https://api.github.com/repos/dlstrong/swc-forklesson/keys{/key_id}",
#             "labels_url": "https://api.github.com/repos/dlstrong/swc-forklesson/labels{/name}",
#             "language": "R",
#             "languages_url": "https://api.github.com/repos/dlstrong/swc-forklesson/languages",
#             "license": null,
#             "merges_url": "https://api.github.com/repos/dlstrong/swc-forklesson/merges",
#             "milestones_url": "https://api.github.com/repos/dlstrong/swc-forklesson/milestones{/number}",
#             "mirror_url": null,
#             "name": "swc-forklesson",
#             "node_id": "MDEwOlJlcG9zaXRvcnkxMTQzMDQ1NTA=",
#             "notifications_url": "https://api.github.com/repos/dlstrong/swc-forklesson/notifications{?since,all,participating}",
#             "open_issues": 8,
#             "open_issues_count": 8,
#             "owner": {
#                 "avatar_url": "https://avatars0.githubusercontent.com/u/3987376?v=4",
#                 "events_url": "https://api.github.com/users/dlstrong/events{/privacy}",
#                 "followers_url": "https://api.github.com/users/dlstrong/followers",
# ...
#                 "subscriptions_url": "https://api.github.com/users/areyeslo/subscriptions",
#                 "type": "User",
#                 "url": "https://api.github.com/users/areyeslo"
#             },
#             "private": false,
#             "pulls_url": "https://api.github.com/repos/areyeslo/PullRequests/pulls{/number}",
#             "pushed_at": "2015-02-24T03:41:53Z",
#             "releases_url": "https://api.github.com/repos/areyeslo/PullRequests/releases{/id}",
#             "score": 9.136508,
#             "size": 22600,
#             "ssh_url": "git@github.com:areyeslo/PullRequests.git",
#             "stargazers_count": 0,
#             "stargazers_url": "https://api.github.com/repos/areyeslo/PullRequests/stargazers",
#             "statuses_url": "https://api.github.com/repos/areyeslo/PullRequests/statuses/{sha}",
#             "subscribers_url": "https://api.github.com/repos/areyeslo/PullRequests/subscribers",
#             "subscription_url": "https://api.github.com/repos/areyeslo/PullRequests/subscription",
#             "svn_url": "https://github.com/areyeslo/PullRequests",
#             "tags_url": "https://api.github.com/repos/areyeslo/PullRequests/tags",
#             "teams_url": "https://api.github.com/repos/areyeslo/PullRequests/teams",
#             "trees_url": "https://api.github.com/repos/areyeslo/PullRequests/git/trees{/sha}",
#             "updated_at": "2015-02-24T03:42:25Z",
#             "url": "https://api.github.com/repos/areyeslo/PullRequests",
#             "watchers": 0,
#             "watchers_count": 0
#         },
#         {
#             "archive_url": "https://api.github.com/repos/codeforsanjose/mySanJose-Requests-Analysis/{archive_format}{/ref}",
#             "archived": false,
#             "assignees_url": "https://api.github.com/repos/codeforsanjose/mySanJose-Requests-Analysis/assignees{/user}",
#             "blobs_url": "https://api.github.com/repos/codeforsanjose/mySanJose-Requests-Analysis/git/blobs{/sha}",
#             "branches_url": "https://api.github.com/repos/codeforsanjose/mySanJose-Requests-Analysis/branches{/branch}",
#             "clone_url": "https://github.com/codeforsanjose/mySanJose-Requests-Analysis.git",
#             "collaborators_url": "https://api.github.com/repos/codeforsanjose/mySanJose-Requests-Analysis/collaborators{/collaborator}",
#             "comments_url": "https://api.github.com/repos/codeforsanjose/mySanJose-Requests-Analysis/comments{/number}",
#             "commits_url": "https://api.github.com/repos/codeforsanjose/mySanJose-Requests-Analysis/commits{/sha}",
#             "compare_url": "https://api.github.com/repos/codeforsanjose/mySanJose-Requests-Analysis/compare/{base}...{head}",
#             "contents_url": "https://api.github.com/repos/codeforsanjose/mySanJose-Requests-Analysis/contents/{+path}",
#             "contributors_url": "https://api.github.com/repos/codeforsanjose/mySanJose-Requests-Analysis/contributors",
#             "created_at": "2018-08-25T18:10:35Z",
#             "default_branch": "master",
#             "deployments_url": "https://api.github.com/repos/codeforsanjose/mySanJose-Requests-Analysis/deployments",
#             "description": "Analyses for mySanJose Requests",
#             "downloads_url": "https://api.github.com/repos/codeforsanjose/mySanJose-Requests-Analysis/downloads",
#             "events_url": "https://api.github.com/repos/codeforsanjose/mySanJose-Requests-Analysis/events",
#             "fork": false,
#             "forks": 0,
#             "forks_count": 0,
#             "forks_url": "https://api.github.com/repos/codeforsanjose/mySanJose-Requests-Analysis/forks",
#             "full_name": "codeforsanjose/mySanJose-Requests-Analysis",
#             "git_commits_url": "https://api.github.com/repos/codeforsanjose/mySanJose-Requests-Analysis/git/commits{/sha}",
#             "git_refs_url": "https://api.github.com/repos/codeforsanjose/mySanJose-Requests-Analysis/git/refs{/sha}",
#             "git_tags_url": "https://api.github.com/repos/codeforsanjose/mySanJose-Requests-Analysis/git/tags{/sha}",
#             "git_url": "git://github.com/codeforsanjose/mySanJose-Requests-Analysis.git",
#             "has_downloads": true,
#             "has_issues": true,
#             "has_pages": false,
#             "has_projects": true,
#             "has_wiki": true,
#             "homepage": null,
#             "hooks_url": "https://api.github.com/repos/codeforsanjose/mySanJose-Requests-Analysis/hooks",
#             "html_url": "https://github.com/codeforsanjose/mySanJose-Requests-Analysis",
#             "id": 146118608,
#             "issue_comment_url": "https://api.github.com/repos/codeforsanjose/mySanJose-Requests-Analysis/issues/comments{/number}",
#             "issue_events_url": "https://api.github.com/repos/codeforsanjose/mySanJose-Requests-Analysis/issues/events{/number}",
#             "issues_url": "https://api.github.com/repos/codeforsanjose/mySanJose-Requests-Analysis/issues{/number}",
#             "keys_url": "https://api.github.com/repos/codeforsanjose/mySanJose-Requests-Analysis/keys{/key_id}",
#             "labels_url": "https://api.github.com/repos/codeforsanjose/mySanJose-Requests-Analysis/labels{/name}",
#             "language": "R",
#             "languages_url": "https://api.github.com/repos/codeforsanjose/mySanJose-Requests-Analysis/languages",
#             "license": {
#                 "key": "mit",
#                 "name": "MIT License",
#                 "node_id": "MDc6TGljZW5zZTEz",
#                 "spdx_id": "MIT",
#                 "url": "https://api.github.com/licenses/mit"
#             },
#             "merges_url": "https://api.github.com/repos/codeforsanjose/mySanJose-Requests-Analysis/merges",
#             "milestones_url": "https://api.github.com/repos/codeforsanjose/mySanJose-Requests-Analysis/milestones{/number}",
#             "mirror_url": null,
#             "name": "mySanJose-Requests-Analysis",
#             "node_id": "MDEwOlJlcG9zaXRvcnkxNDYxMTg2MDg=",
#             "notifications_url": "https://api.github.com/repos/codeforsanjose/mySanJose-Requests-Analysis/notifications{?since,all,participating}",
#             "open_issues": 0,
#             "open_issues_count": 0,
#             "owner": {
#                 "avatar_url": "https://avatars2.githubusercontent.com/u/6627417?v=4",
#                 "events_url": "https://api.github.com/users/codeforsanjose/events{/privacy}",
#                 "followers_url": "https://api.github.com/users/codeforsanjose/followers",
#                 "following_url": "https://api.github.com/users/codeforsanjose/following{/other_user}",
#                 "gists_url": "https://api.github.com/users/codeforsanjose/gists{/gist_id}",
#                 "gravatar_id": "",
#                 "html_url": "https://github.com/codeforsanjose",
#                 "id": 6627417,
#                 "login": "codeforsanjose",
#                 "node_id": "MDEyOk9yZ2FuaXphdGlvbjY2Mjc0MTc=",
#                 "organizations_url": "https://api.github.com/users/codeforsanjose/orgs",
#                 "received_events_url": "https://api.github.com/users/codeforsanjose/received_events",
#                 "repos_url": "https://api.github.com/users/codeforsanjose/repos",
#                 "site_admin": false,
#                 "starred_url": "https://api.github.com/users/codeforsanjose/starred{/owner}{/repo}",
#                 "subscriptions_url": "https://api.github.com/users/codeforsanjose/subscriptions",
#                 "type": "Organization",
#                 "url": "https://api.github.com/users/codeforsanjose"
#             },
#             "private": false,
#             "pulls_url": "https://api.github.com/repos/codeforsanjose/mySanJose-Requests-Analysis/pulls{/number}",
#             "pushed_at": "2018-10-23T20:15:40Z",
#             "releases_url": "https://api.github.com/repos/codeforsanjose/mySanJose-Requests-Analysis/releases{/id}",
#             "score": 9.111044,
#             "size": 503,
#             "ssh_url": "git@github.com:codeforsanjose/mySanJose-Requests-Analysis.git",
#             "stargazers_count": 0,
#             "stargazers_url": "https://api.github.com/repos/codeforsanjose/mySanJose-Requests-Analysis/stargazers",
#             "statuses_url": "https://api.github.com/repos/codeforsanjose/mySanJose-Requests-Analysis/statuses/{sha}",
#             "subscribers_url": "https://api.github.com/repos/codeforsanjose/mySanJose-Requests-Analysis/subscribers",
#             "subscription_url": "https://api.github.com/repos/codeforsanjose/mySanJose-Requests-Analysis/subscription",
#             "svn_url": "https://github.com/codeforsanjose/mySanJose-Requests-Analysis",
#             "tags_url": "https://api.github.com/repos/codeforsanjose/mySanJose-Requests-Analysis/tags",
#             "teams_url": "https://api.github.com/repos/codeforsanjose/mySanJose-Requests-Analysis/teams",
#             "trees_url": "https://api.github.com/repos/codeforsanjose/mySanJose-Requests-Analysis/git/trees{/sha}",
#             "updated_at": "2018-10-23T20:15:41Z",
#             "url": "https://api.github.com/repos/codeforsanjose/mySanJose-Requests-Analysis",
#             "watchers": 0,
#             "watchers_count": 0
#         },
#         {
#             "archive_url": "https://api.github.com/repos/dewittpe/R-install-dependencies/{archive_format}{/ref}",
#             "archived": false,
#             "assignees_url": "https://api.github.com/repos/dewittpe/R-install-dependencies/assignees{/user}",
#             "blobs_url": "https://api.github.com/repos/dewittpe/R-install-dependencies/git/blobs{/sha}",
#             "branches_url": "https://api.github.com/repos/dewittpe/R-install-dependencies/branches{/branch}",
#             "clone_url": "https://github.com/dewittpe/R-install-dependencies.git",
#             "collaborators_url": "https://api.github.com/repos/dewittpe/R-install-dependencies/collaborators{/collaborator}",
#             "comments_url": "https://api.github.com/repos/dewittpe/R-install-dependencies/comments{/number}",
#             "commits_url": "https://api.github.com/repos/dewittpe/R-install-dependencies/commits{/sha}",
#             "compare_url": "https://api.github.com/repos/dewittpe/R-install-dependencies/compare/{base}...{head}",
#             "contents_url": "https://api.github.com/repos/dewittpe/R-install-dependencies/contents/{+path}",
#             "contributors_url": "https://api.github.com/repos/dewittpe/R-install-dependencies/contributors",
#             "created_at": "2018-02-25T05:37:20Z",
#             "default_branch": "master",
#             "deployments_url": "https://api.github.com/repos/dewittpe/R-install-dependencies/deployments",
#             "description": "A script for gathering and installing dependency packages for an R project in the case that external http(s) requests cannot be made.",
#             "downloads_url": "https://api.github.com/repos/dewittpe/R-install-dependencies/downloads",
#             "events_url": "https://api.github.com/repos/dewittpe/R-install-dependencies/events",
#             "fork": false,
#             "forks": 2,
#             "forks_count": 2,
#             "forks_url": "https://api.github.com/repos/dewittpe/R-install-dependencies/forks",
#             "full_name": "dewittpe/R-install-dependencies",
#             "git_commits_url": "https://api.github.com/repos/dewittpe/R-install-dependencies/git/commits{/sha}",
#             "git_refs_url": "https://api.github.com/repos/dewittpe/R-install-dependencies/git/refs{/sha}",
#             "git_tags_url": "https://api.github.com/repos/dewittpe/R-install-dependencies/git/tags{/sha}",
#             "git_url": "git://github.com/dewittpe/R-install-dependencies.git",
#             "has_downloads": true,
#             "has_issues": true,
#             "has_pages": false,
#             "has_projects": true,
#             "has_wiki": true,
#             "homepage": null,
#             "hooks_url": "https://api.github.com/repos/dewittpe/R-install-dependencies/hooks",
#             "html_url": "https://github.com/dewittpe/R-install-dependencies",
#             "id": 122808469,
#             "issue_comment_url": "https://api.github.com/repos/dewittpe/R-install-dependencies/issues/comments{/number}",
#             "issue_events_url": "https://api.github.com/repos/dewittpe/R-install-dependencies/issues/events{/number}",
#             "issues_url": "https://api.github.com/repos/dewittpe/R-install-dependencies/issues{/number}",
#             "keys_url": "https://api.github.com/repos/dewittpe/R-install-dependencies/keys{/key_id}",
#             "labels_url": "https://api.github.com/repos/dewittpe/R-install-dependencies/labels{/name}",
#             "language": "R",
#             "languages_url": "https://api.github.com/repos/dewittpe/R-install-dependencies/languages",
#             "license": null,
#             "merges_url": "https://api.github.com/repos/dewittpe/R-install-dependencies/merges",
#             "milestones_url": "https://api.github.com/repos/dewittpe/R-install-dependencies/milestones{/number}",
#             "mirror_url": null,
#             "name": "R-install-dependencies",
#             "node_id": "MDEwOlJlcG9zaXRvcnkxMjI4MDg0Njk=",
#             "notifications_url": "https://api.github.com/repos/dewittpe/R-install-dependencies/notifications{?since,all,participating}",
#             "open_issues": 0,
#             "open_issues_count": 0,
#             "owner": {
#                 "avatar_url": "https://avatars1.githubusercontent.com/u/3136617?v=4",
#                 "events_url": "https://api.github.com/users/dewittpe/events{/privacy}",
#                 "followers_url": "https://api.github.com/users/dewittpe/followers",
#                 "following_url": "https://api.github.com/users/dewittpe/following{/other_user}",
#                 "gists_url": "https://api.github.com/users/dewittpe/gists{/gist_id}",
#                 "gravatar_id": "",
#                 "html_url": "https://github.com/dewittpe",
#                 "id": 3136617,
#                 "login": "dewittpe",
#                 "node_id": "MDQ6VXNlcjMxMzY2MTc=",
#                 "organizations_url": "https://api.github.com/users/dewittpe/orgs",
#                 "received_events_url": "https://api.github.com/users/dewittpe/received_events",
#                 "repos_url": "https://api.github.com/users/dewittpe/repos",
#                 "site_admin": false,
#                 "starred_url": "https://api.github.com/users/dewittpe/starred{/owner}{/repo}",
#                 "subscriptions_url": "https://api.github.com/users/dewittpe/subscriptions",
#                 "type": "User",
#                 "url": "https://api.github.com/users/dewittpe"
#             },
#             "private": false,
#             "pulls_url": "https://api.github.com/repos/dewittpe/R-install-dependencies/pulls{/number}",
#             "pushed_at": "2019-01-16T17:52:54Z",
#             "releases_url": "https://api.github.com/repos/dewittpe/R-install-dependencies/releases{/id}",
#             "score": 8.703108,
#             "size": 19,
#             "ssh_url": "git@github.com:dewittpe/R-install-dependencies.git",
#             "stargazers_count": 5,
#             "stargazers_url": "https://api.github.com/repos/dewittpe/R-install-dependencies/stargazers",
#             "statuses_url": "https://api.github.com/repos/dewittpe/R-install-dependencies/statuses/{sha}",
#             "subscribers_url": "https://api.github.com/repos/dewittpe/R-install-dependencies/subscribers",
#             "subscription_url": "https://api.github.com/repos/dewittpe/R-install-dependencies/subscription",
#             "svn_url": "https://github.com/dewittpe/R-install-dependencies",
#             "tags_url": "https://api.github.com/repos/dewittpe/R-install-dependencies/tags",
#             "teams_url": "https://api.github.com/repos/dewittpe/R-install-dependencies/teams",
#             "trees_url": "https://api.github.com/repos/dewittpe/R-install-dependencies/git/trees{/sha}",
#             "updated_at": "2019-01-16T17:52:56Z",
#             "url": "https://api.github.com/repos/dewittpe/R-install-dependencies",
#             "watchers": 5,
#             "watchers_count": 5
#         }
#     ],
#     "total_count": 150
# }

# %% [markdown]
# ## Customize requests headers

# %%
import requests
resp = requests.get('https://api.github.com/search/repositories', 
                    params={'q':'requests+language:python'}, 
                    headers={'accept': 'application/vnd.github.v3.text-match+json'})
json_resp = res.json()
repo = json_resp['items'][0]
print(repo)
print(repo['keys_url'])

# NOTE: The Accept header tells the server what content types your application can handle. 
# The header value 'application/vnd.github.v3.text-match+json' is a proprietary Github header
# Out:
# {'id': 1362490, 'node_id': 'MDEwOlJlcG9zaXRvcnkxMzYyNDkw', 'name': 'requests', 'full_name': 'kennethreitz/requests', 'private': False, 'owner': {'login': 'kennethreitz', 'id': 47496974, 'node_id': 'MDEyOk9yZ2FuaXphdGlvbjQ3NDk2OTc0', 'avatar_url': 'https://avatars1.githubusercontent.com/u/47496974?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/kennethreitz', 'html_url': 'https://github.com/kennethreitz', 'followers_url': 'https://api.github.com/users/kennethreitz/followers', 'following_url': 'https://api.github.com/users/kennethreitz/following{/other_user}', 'gists_url': 'https://api.github.com/users/kennethreitz/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/kennethreitz/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/kennethreitz/subscriptions', 'organizations_url': 'https://api.github.com/users/kennethreitz/orgs', 'repos_url': 'https://api.github.com/users/kennethreitz/repos', 'events_url': 'https://api.github.com/users/kennethreitz/events{/privacy}', 'received_events_url': 'https://api.github.com/users/kennethreitz/received_events', 'type': 'Organization', 'site_admin': False}, 'html_url': 'https://github.com/kennethreitz/requests', 'description': 'Python HTTP Requests for Humans™ ✨🍰✨', 'fork': False, 'url': 'https://api.github.com/repos/kennethreitz/requests', 'forks_url': 'https://api.github.com/repos/kennethreitz/requests/forks', 'keys_url': 'https://api.github.com/repos/kennethreitz/requests/keys{/key_id}', 'collaborators_url': 'https://api.github.com/repos/kennethreitz/requests/collaborators{/collaborator}', 'teams_url': 'https://api.github.com/repos/kennethreitz/requests/teams', 'hooks_url': 'https://api.github.com/repos/kennethreitz/requests/hooks', 'issue_events_url': 'https://api.github.com/repos/kennethreitz/requests/issues/events{/number}', 'events_url': 'https://api.github.com/repos/kennethreitz/requests/events', 'assignees_url': 'https://api.github.com/repos/kennethreitz/requests/assignees{/user}', 'branches_url': 'https://api.github.com/repos/kennethreitz/requests/branches{/branch}', 'tags_url': 'https://api.github.com/repos/kennethreitz/requests/tags', 'blobs_url': 'https://api.github.com/repos/kennethreitz/requests/git/blobs{/sha}', 'git_tags_url': 'https://api.github.com/repos/kennethreitz/requests/git/tags{/sha}', 'git_refs_url': 'https://api.github.com/repos/kennethreitz/requests/git/refs{/sha}', 'trees_url': 'https://api.github.com/repos/kennethreitz/requests/git/trees{/sha}', 'statuses_url': 'https://api.github.com/repos/kennethreitz/requests/statuses/{sha}', 'languages_url': 'https://api.github.com/repos/kennethreitz/requests/languages', 'stargazers_url': 'https://api.github.com/repos/kennethreitz/requests/stargazers', 'contributors_url': 'https://api.github.com/repos/kennethreitz/requests/contributors', 'subscribers_url': 'https://api.github.com/repos/kennethreitz/requests/subscribers', 'subscription_url': 'https://api.github.com/repos/kennethreitz/requests/subscription', 'commits_url': 'https://api.github.com/repos/kennethreitz/requests/commits{/sha}', 'git_commits_url': 'https://api.github.com/repos/kennethreitz/requests/git/commits{/sha}', 'comments_url': 'https://api.github.com/repos/kennethreitz/requests/comments{/number}', 'issue_comment_url': 'https://api.github.com/repos/kennethreitz/requests/issues/comments{/number}', 'contents_url': 'https://api.github.com/repos/kennethreitz/requests/contents/{+path}', 'compare_url': 'https://api.github.com/repos/kennethreitz/requests/compare/{base}...{head}', 'merges_url': 'https://api.github.com/repos/kennethreitz/requests/merges', 'archive_url': 'https://api.github.com/repos/kennethreitz/requests/{archive_format}{/ref}', 'downloads_url': 'https://api.github.com/repos/kennethreitz/requests/downloads', 'issues_url': 'https://api.github.com/repos/kennethreitz/requests/issues{/number}', 'pulls_url': 'https://api.github.com/repos/kennethreitz/requests/pulls{/number}', 'milestones_url': 'https://api.git ...
# https://api.github.com/repos/kennethreitz/requests/keys{/key_id}

# %% [markdown]
# ## Requests- to make HTTP HEAD request

# %%
resp = requests.head("https://httpbin.org/head")
print(resp.headers["content-type"])
# Out:
# text/html

# %% [markdown]
# ## Requests- to make HTTP DELETE request

# %%
resp = requests.delete("https://httpbin.org/delete")
json_resp = resp.json()
json_resp["args"]
# Out:
# {}

# %% [markdown]
# ## Concept of The Messsage Body:
# ### Unlike GET, where in the request parameters are passed in the query string, in HTTP POST, PUT and PATCH, the data is passed through the message body.
#
# ### Data could be a dictionary/ a list of tuples, bytes or a file object.

# %%
# For example:
resp = requests.post('https://httpbin.org/post', data={'key':'value'})     # Pass as a dictionary
print(resp)


resp = requests.post('https://httpbin.org/post', data=[('key', 'value')])
print(resp)

# NOTE: httpbin.org is a great resource created by the author of requests, Kenneth Reitz. 
# It’s a service that accepts test requests and responds with data about the requests
# Out:
# <Response [200]>
# <Response [200]>

# %% [markdown]
# ## Inspecting the requests -
# ### When you make a request, the requests library prepares the request, before actually sending it to the destination server. Request preparation includes things like:
# ### - Validating headers
# ### - Serializing JSON Content etc...
#
# ### You have to view the "PreparedRequest" by accessing .request of the response

# %%
# For e.g. 
resp = requests.post("https://httpbin.org/post", data=[('key','value')])
print(resp.request.headers['Content-Type'])
print(resp.request.url)
print(resp.request.body)
# Out:
# application/x-www-form-urlencoded
# https://httpbin.org/post
# key=value

# %% [markdown]
# ## Request Authentication:
# ### Few web services require you to authenticate yourself, before the service is rendered [Basic/OAuth/ custom Authentication defined by you...]
# ### The service needs to know, your identity.
# ### This needs you to include the 'Authorization' header or any custom header defined by the service.
#
# ### All the requests methods provide a parameter called "auth", whic allows you to pass your credentials.

# %%
from getpass import getpass               # Prompt the user for a password without echoing
requests.get("https://api.github.com/user", auth=('silver1icicle', getpass()))

# NOTE: 
# If the username and password you supplied were authenticated, you get the response <200>, else you get the response <401>
# When you supply your username and password, requests applies the credentials using the HTTP's Basic Authentication (BA) scheme.
# The BA scheme doesnt protect your credentials while transmitting. The creds are ,erely encoded with Base64 but not encrypted 
# or hashed in any way. Thus BA is usually used along with HTTPS to confor confidentiality. 

# BA is the simplest technique for enforcing access controls, to web resources, as it does not require cookies, 
# session identifiers or login pages. It uses standard fields in the HTTP headers, removing the need for handshakes.
# Out:
# ········
# <Response [200]>

# %%
# Alternative way for basic authentication
from requests.auth import HTTPBasicAuth
from getpass import getpass
requests.get('https://api.github.com/user', auth=HTTPBasicAuth('silver1icicle', getpass()))
# Out:
# ········
# <Response [200]>

# %%
# Various authentication methods offered by requests:
# 1. HTTPBasicAuth
# 2. HTTPDigestAuth
# 3. HTTPProxyAuth

# %% [markdown]
# ## SSL Certification Verification
# ### If the data shared by you is sensitive, security is important. Communication with secure websites over HTTP, involves establishing an encrypted connection using SSL i.e. verfiying the target server's SSL Certificate.
# ### requests does this by default. In case you wish to change this behavior (not recommended) i.e. disable SSL Certification Verification, pass 'False', to the 'verify' parameter of the request function. However it will issue you a critical warning, regarding your data being unsafe.
#
# ### requests internally makes use of the package 'certifi'.

# %%
resp = requests.get("https://api.github.com", verify=False)
# Out:
# C:\Users\parul\Anaconda3\lib\site-packages\requests\packages\urllib3\connectionpool.py:843: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)

# %% [markdown]
# ## Achieving performance with requests [For production environments]
# ### Using:
# ### 1. Timeout control:
# ### When you make a request, you have to wait for the external server to respond. If the server takes forever to respond, this could frustate the user or hang any of the other background services. By default, requests waits indefinitely for the response. We can however specify a "timeout" duration, to prevent these things from happening. Timeout can be specified as 'Integer' or 'float' == Number of seconds to wait before timing out. In the event that the timeout occurs, Timeout exception is raised.
#
# ### 2. Sessions:
# ### The requests get() and post() are high level API's which abstract majority of the internal operations, such as sessions. In case you need to control, how requests are managed, you may need to use a Session instance directly. Sessions are used to persist parameters across requests. For e.g. if you need to use the same authentication across multiple requests, use session
#
# ### 3. Retry limits:
# ### When a request fails, you may want your application to retry the same request. requests doesnt do that by default. To apply this functionality, you need to implement a custom TransportAdapter. These adapters help you define a set of custom configurations/ service you are interacting with. For e.g. Try all requests to "https://api.github.com" atleast 3 times, before raising a ConnectionError. Steps:
#
# ### 3.1] Build a transport adapter
# ### 3.2] Set the max_retries parameter
# ### 3.3] Mount to an exiting session
#
#
# ## Summary:
# ### All these three strategies viz...Timeout, Sessions and Retry Limits are used to keep your code efficient + your application resilient.

# %%
# Demo of timeout
resp = requests.get("https://api.github.com", timeout=1)     # 1 sec timeout duration...success
print(resp)

resp = requests.get("https://api.github.com", timeout=0.5)  # 0.5 sec timeout duration...success. 
print(resp)

resp = requests.get("https://api.github.com", timeout=(2,5))   # Wait 2 sec...for establishing connection with the server
print(resp)                                                    # Wait 5 sec...for the server to respond. 


# Timeout exception
from requests.exceptions import Timeout
try:
    resp = requests.get('https://api.github.com', timeout=0.05)
    print(res)
except Timeout:
    print("The request timed out")
else:
    print("The server responded timely")
# Out:
# <Response [200]>
# <Response [200]>
# <Response [200]>
# The request timed out

# %%
# Demo of sessions
import requests
from getpass import getpass

# Here we use the context manager 'with', to ensure resources used by the session will be released after use
with requests.Session() as ss:                         
    ss.auth=('silver1icicle', getpass())               
    resp = ss.get('https://api.github.com/user')     # Instead of requests.get() use the sessions instance. 
    
print(resp.json())
print(resp.headers)
# Out:
# ········
# {'login': 'silver1icicle', 'id': 45722967, 'node_id': 'MDQ6VXNlcjQ1NzIyOTY3', 'avatar_url': 'https://avatars1.githubusercontent.com/u/45722967?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/silver1icicle', 'html_url': 'https://github.com/silver1icicle', 'followers_url': 'https://api.github.com/users/silver1icicle/followers', 'following_url': 'https://api.github.com/users/silver1icicle/following{/other_user}', 'gists_url': 'https://api.github.com/users/silver1icicle/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/silver1icicle/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/silver1icicle/subscriptions', 'organizations_url': 'https://api.github.com/users/silver1icicle/orgs', 'repos_url': 'https://api.github.com/users/silver1icicle/repos', 'events_url': 'https://api.github.com/users/silver1icicle/events{/privacy}', 'received_events_url': 'https://api.github.com/users/silver1icicle/received_events', 'type': 'User', 'site_admin': False, 'name': 'Silver Icicle', 'company': None, 'blog': '', 'location': None, 'email': None, 'hireable': None, 'bio': None, 'public_repos': 6, 'public_gists': 0, 'followers': 0, 'following': 0, 'created_at': '2018-12-08T23:19:43Z', 'updated_at': '2019-01-21T10:08:03Z', 'private_gists': 0, 'total_private_repos': 0, 'owned_private_repos': 0, 'disk_usage': 8166, 'collaborators': 0, 'two_factor_authentication': False, 'plan': {'name': 'free', 'space': 976562499, 'collaborators': 0, 'private_repos': 10000}}
# {'Server': 'GitHub.com', 'Date': 'Tue, 12 Mar 2019 19:09:46 GMT', 'Content-Type': 'application/json; charset=utf-8', 'Transfer-Encoding': 'chunked', 'Status': '200 OK', 'X-RateLimit-Limit': '5000', 'X-RateLimit-Remaining': '4997', 'X-RateLimit-Reset': '1552421375', 'Cache-Control': 'private, max-age=60, s-maxage=60', 'Vary': 'Accept, Authorization, Cookie, X-GitHub-OTP', 'ETag': 'W/"63a5b9922bb46e9cd29bb18f1b70282a"', 'Last-Modified': 'Mon, 21 Jan 2019 10:08:03 GMT', 'X-GitHub-Media-Type': 'github.v3; format=json', 'Access-Control-Expose-Headers': 'ETag, Link, Location, Retry-After, X-GitHub-OTP, X-RateLimit-Limit, X-RateLimit-Remaining, X-RateLimit-Reset, X-OAuth-Scopes, X-Accepted-OAuth-Scopes, X-Poll-Interval, X-GitHub-Media-Type', 'Access-Control-Allow-Origin': '*', 'Strict-Transport-Security': 'max-age=31536000; includeSubdomains; preload', 'X-Frame-Options': 'deny', 'X-Content-Type-Options': 'nosniff', 'X-XSS-Protection': '1; mode=block', 'Referrer-Policy': 'origin-when-cross-origin, strict-origin-when-cross-origin', 'Content-Security-Policy': "default-src 'none'", 'Content-Encoding': 'gzip', 'X-GitHub-Request-Id': 'C72B:6833:4187D:B725C:5C8803FA'}

# %%
# Demo of max retries
import requests
from requests.adapters import HTTPAdapter
from requests.exceptions import ConnectionError

githubCustomAdapter = HTTPAdapter(max_retries=3)                # Custom adapter with configuration setting
ss = requests.Session()                                         # Create an instance of Session 
ss.mount("https://api.github.com", githubCustomAdapter)    # Mount the custom adapter to an existing session

try:
    resp = ss.get("https://api.github.com")
    print(resp.json())
except ConnectionError as ce:
    print(ce)
# Out:
# {'current_user_url': 'https://api.github.com/user', 'current_user_authorizations_html_url': 'https://github.com/settings/connections/applications{/client_id}', 'authorizations_url': 'https://api.github.com/authorizations', 'code_search_url': 'https://api.github.com/search/code?q={query}{&page,per_page,sort,order}', 'commit_search_url': 'https://api.github.com/search/commits?q={query}{&page,per_page,sort,order}', 'emails_url': 'https://api.github.com/user/emails', 'emojis_url': 'https://api.github.com/emojis', 'events_url': 'https://api.github.com/events', 'feeds_url': 'https://api.github.com/feeds', 'followers_url': 'https://api.github.com/user/followers', 'following_url': 'https://api.github.com/user/following{/target}', 'gists_url': 'https://api.github.com/gists{/gist_id}', 'hub_url': 'https://api.github.com/hub', 'issue_search_url': 'https://api.github.com/search/issues?q={query}{&page,per_page,sort,order}', 'issues_url': 'https://api.github.com/issues', 'keys_url': 'https://api.github.com/user/keys', 'notifications_url': 'https://api.github.com/notifications', 'organization_repositories_url': 'https://api.github.com/orgs/{org}/repos{?type,page,per_page,sort}', 'organization_url': 'https://api.github.com/orgs/{org}', 'public_gists_url': 'https://api.github.com/gists/public', 'rate_limit_url': 'https://api.github.com/rate_limit', 'repository_url': 'https://api.github.com/repos/{owner}/{repo}', 'repository_search_url': 'https://api.github.com/search/repositories?q={query}{&page,per_page,sort,order}', 'current_user_repositories_url': 'https://api.github.com/user/repos{?type,page,per_page,sort}', 'starred_url': 'https://api.github.com/user/starred{/owner}{/repo}', 'starred_gists_url': 'https://api.github.com/gists/starred', 'team_url': 'https://api.github.com/teams', 'user_url': 'https://api.github.com/users/{user}', 'user_organizations_url': 'https://api.github.com/user/orgs', 'user_repositories_url': 'https://api.github.com/users/{user}/repos{?type,page,per_page,sort}', 'user_search_url': 'https://api.github.com/search/users?q={query}{&page,per_page,sort,order}'}
